# %%
# %%html
# <style>
#   table {margin-left: 0 !important;}
# </style>
# Out:
# <style>
#   table {margin-left: 0 !important;}
# </style>

# %% [markdown]
# # Detecção de rostos com uso de máscara de proteção para COVID-19
#
# ## Trabalho em Grupo
# - **Curso:** FGV MBA - Business Analytics e Big Data
# - **Disciplina:** Análise Econômica e Geração de Valor
# - **Professor:** Bernardo Aflalo
# - **Projeto final:** Detecção de rostos com uso de máscara de proteção
#
# ## Integrantes
# |Github|Kaggle|Nome|Matricula|E-mail|
# |---|---|---|---|---|
# |<a href="https://github.com/DanielFCampos"><img src="https://avatars2.githubusercontent.com/u/31582602?s=460&v=4" title="DanielFCampos" width="40" height="40"></a>|<a href="https://www.kaggle.com/danielferrazcampos"><img src="https://storage.googleapis.com/kaggle-avatars/images/3508055-kg.png" title="DanielFCampos" width="40" height="40"></a>|Daniel Campos|A57635769|[daniel.ferraz.campos@gmail.com](daniel.ferraz.campos@gmail.com)|
# |<a href="https://github.com/ldaniel"><img src="https://avatars2.githubusercontent.com/u/205534?s=460&v=4" title="ldaniel" width="40" height="40"></a>|<a href="https://www.kaggle.com/leandrodaniel"><img src="https://storage.googleapis.com/kaggle-avatars/images/3415144-gr.jpg" title="ldaniel" width="40" height="40"></a>|Leandro Daniel|A57622988|[contato@leandrodaniel.com](contato@leandrodaniel.com)|
# |<a href="https://github.com/ricardobreis"><img src="https://avatars2.githubusercontent.com/u/4885152?s=460&u=470b0bcc829715fd3944d921fec99ad0ea2d6263&v=4" title="ricardobreis" width="40" height="40"></a>|<a href="https://www.kaggle.com/ricardobreis"><img src="https://storage.googleapis.com/kaggle-avatars/images/3201976-kg.jpg" title="ricardobreis" width="40" height="40"></a>|Ricardo Reis|A57590919|[ricardo.l.b.reis@gmail.com](ricardo.l.b.reis@gmail.com)|
# |<a href="https://github.com/RodriGonca"><img src="https://avatars2.githubusercontent.com/u/50252438?s=460&v=4" title="RodriGonca" width="40" height="40"></a>|<a href="https://www.kaggle.com/rodrigonca"><img src="https://storage.googleapis.com/kaggle-avatars/images/3511253-kg.png" title="RodriGonca" width="40" height="40"></a>|Rodrigo Gonçalves|A57566093|[rodrigo.goncalves@me.com](rodrigo.goncalves@me.com)|
# |<a href="https://github.com/ygorlima1"><img src="https://avatars2.githubusercontent.com/u/52429828?s=460&v=4" title="ygorlima1" width="40" height="40"></a>|<a href="https://www.kaggle.com/ygorlima1"><img src="https://storage.googleapis.com/kaggle-avatars/images/3427786-kg.jpg" title="ygorlima1" width="40" height="40"></a>|Ygor Lima|A57549661|[ygor_redesocial@hotmail.com](ygor_redesocial@hotmail.com)|
#
# ## Enunciado
#
# O trabalho poderá ser feito em até 5 pessoas.
#
# O objetivo do trabalho deve contemplar assuntos da aula (deep neural network, convolutional neural network, recurrent neural network) e deve ser escolhido por cada grupo. Na nossa última aula, dia 15/06, os alunos devem apresentar o grupo e qual o tema e o objetivo específico do trabalho. Ex.: 'O grupo, composto pelos alunos (...), terá como trabalho a estimativa dos casos de covid no Brasil utilizando arquiteturas de redes recorrentes, como LSTM e GRU.' Os grupos que tiverem dificuldade de escolher projetos, podem entrar em contato comigo. Algumas sugestões/ inspirações podem ser obtidas em sites de competição (ex Kaggle), mas a solução final deve conter elementos originais.
#
# A entrega final deve ser feita individualmente por cada aluno até o dia 31/07 e deverá conter:
#
# * Os notebooks/ scripts com o trabalho feito e as soluções produzidas pelo grupo (comum a todos os membros do grupo);
#
# * Documentação individual, explicando o que foi feito no trabalho, problemas encontrados e possibilidades de melhoria da solução, em formato de 'mini papers' (2-5 páginas). Cada um deve ter a sua submissão de mini-paper.

# %% [markdown]
# # Desenvolvimento
#
# ## Contexto do trabalho
#
# Vivemos tempos singulares, onde nossa sociedade enfrenta o desafio de combate e prevenção contra o crescente alastramento da COVID-19 em uma escala global. Deste desafiador contexto, emergem efeitos colaterais inéditos na era moderna, como o distanciamento social, dentre diversas mudanças de hábitos.
#
# Com base nas evidências atuais, o vírus COVID-19 é transmitido entre pessoas através de contato próximo e gotículas. Calcula-se que uma pessoa com infecção o transmita para de duas a quatro pessoas.
#
# A Organização Mundial de Saúde (OMS) recomenda o uso de máscaras combinadas com a correta higiene frequente das mãos como parte da chamada EPI (Equipamento de Proteção Individual, do inglês PPE, ou Personal Protective Equipment), dentre outras orientações e recomendações. A Organização Mundial de Saúde disponibiliza uma série de orientações e guias para o uso correto das máscaras, bem com seu descarte e combinação com procedimentos de lavagem das mãos, como uma das medidas possíveis de contenção do alastramento da
# COVID-19.
#
# Recentemente o estado de São Paulo decretou o uso de máscaras de proteção facial como obrigatório, por tempo indeterminado. A medida, que entrou em vigor em 07/05/2020, estabelece o seguinte:
#
# **Uso de máscaras em:**
# * espaços públicos;
# * estabelecimentos que executem atividades essenciais;
# * repartições públicas estaduais;
# * transporte por aplicativo.
#
# **Usados por:**
# * consumidores;
# * fornecedores;
# * clientes;
# * empregados;
# * colaboradores;
# * agentes públicos;
# * prestadores de serviço.
#
#
# ## Objetivos do trabalho
#
# O presente trabalho tem como objetivo principal, desenvolver um modelo de detecção de indivíduos utilizando máscaras faciais, através de técnicas de Deep Learning, como ferramenta possível de ser implementada em sistemas de monitoramento preventivo ao alastramento da COVID-19 em locais e áreas de convívio público ou privado.
#
# ## Pergunta do problema
#
# É possível desenvolver, com técnicas de deep learning, um modelo de detecção de pessoas utilizando máscaras faciais para posterior implementação em sistemas de controle de entrada em espaços públicos, estabelecimentos que executem atividades essenciais, repartições públicas estaduais, transporte por aplicativo para um público alvo de consumidores,  fornecedores,  clientes, empregados, colaboradores, agentes públicos e  prestadores de serviço?

# %% [markdown]
# ## Libraries Utilizadas para Desenvolvimento da Análise

# %%
import os
import numpy as np
import pandas as pd
import random


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import load_img, img_to_array

import cv2 as cv
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, roc_curve, auc, classification_report

from IPython.display import Markdown as md
from PIL import Image

# %%
seed = 42

random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Data Preparation

# %%
image_size = 256
labels = ['without_mask', 'with_mask']

def get_data(data_dir):
        
    images = []
    
# cria uma lista com o index de cada label com base no nome da raíz do diretório informado.
    for label in labels:
        dir = os.path.join(data_dir, label)
        class_num = labels.index(label)
        
# percorre todas as imagens presentes no diretório, converte para grey_sacale e faz o resizing das imagens.
        for image in os.listdir(dir):    
            image_read = cv.imread(os.path.join(dir,image), cv.IMREAD_GRAYSCALE)
            image_resized = cv.resize(image_read, (image_size, image_size))
            images.append([image_resized, class_num])

    return np.array(images)

load_full_dataset = get_data('/kaggle/input/data/raw/artificially_created_covid_mask_images/')

# %%
mask_count = np.count_nonzero(load_full_dataset[:,1] == 1)
no_mask_count = np.count_nonzero(load_full_dataset[:,1] == 0)

print('Dataset original\n\n', len(load_full_dataset),
      'imagens no dataset com o tamanho', load_full_dataset[1,0].shape,
      '\n\nProporção',
      '\nSem máscara:\t', no_mask_count,
      '\nCom máscara:\t', mask_count)
# Out:
# Dataset original
#
#  1376 imagens no dataset com o tamanho (256, 256)
#
# Proporção
# Sem máscara:	 686
# Com máscara:	 690

# %%
plt.rcParams.update({'font.size': 16})

fig = plt.figure(figsize = (12, 12))
columns = 4
rows = 3

randomlist = []

for i in range(0, int((columns * rows)/2)):
    n = np.random.randint(0, np.count_nonzero(load_full_dataset[:,1] == 0))
    randomlist.append(n)
    
for i in range(0, int((columns * rows)/2)):
    n = np.random.randint(np.count_nonzero(load_full_dataset[:,1] == 0), len(load_full_dataset))
    randomlist.append(n)
    
for i in range(1, columns * rows + 1):
    rnd = np.random.randint(0, len(load_full_dataset))
    img = load_full_dataset[randomlist[i-1]][0]  
    fig.add_subplot(rows, columns, i)
    plt.title(labels[load_full_dataset[randomlist[i-1]][1]])
    plt.axis('off')
    plt.imshow(img, cmap='gray')

plt.show()

# %%
x_features = []
y_labels = []

for feature, label in load_full_dataset:
    x_features.append(feature)
    y_labels.append(label)
    
del load_full_dataset

# %%
x_features = np.array(x_features).reshape(-1, image_size, image_size, 1)
y_labels = np.array(y_labels)
y_labels = np.expand_dims(y_labels, axis =1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_features, 
                                                    y_labels,
                                                    stratify = y_labels,
                                                    test_size = 0.2, 
                                                    random_state = 2)

del x_features, y_labels

# %%
print('\nTensor de features de treinamento:\t', x_train.shape, 
      '\nImagens:\t', len(x_train), 
      '\nSem máscara:\t', np.count_nonzero(y_train == 0), 
      '\nCom máscara:\t', np.count_nonzero(y_train == 1))

print('\nTensor de labels de treinamento:\t', y_train.shape, 
      '\nQuantidade:\t', len(y_train),
      '\nSem máscara:\t', np.count_nonzero(y_train == 0), 
      '\nCom máscara:\t', np.count_nonzero(y_train == 1))

print('\nTensor de features de teste:\t\t', x_test.shape, 
      '\nImagens:\t', len(x_test),
      '\nSem máscara:\t', np.count_nonzero(y_test == 0), 
      '\nCom máscara:\t', np.count_nonzero(y_test == 1))

print('\nTensor de labels de teste:\t\t', y_test.shape, 
      '\nQuantidade:\t', len(y_test),
      '\nSem máscara:\t', np.count_nonzero(y_test == 0), 
      '\nCom máscara:\t', np.count_nonzero(y_test == 1))
# Out:
# Tensor de features de treinamento:	 (1100, 256, 256, 1)
# Imagens:	 1100
# Sem máscara:	 548
# Com máscara:	 552
#
# Tensor de labels de treinamento:	 (1100, 1)
# Quantidade:	 1100
# Sem máscara:	 548
# Com máscara:	 552
#
# Tensor de features de teste:		 (276, 256, 256, 1)
# Imagens:	 276
# Sem máscara:	 138
# Com máscara:	 138
#
# Tensor de labels de teste:		 (276, 1)
# Quantidade:	 276
# Sem máscara:	 138
# Com máscara:	 138

# %%
x_train = x_train / 255
x_test  = x_test  / 255

# %% [markdown]
# ## Definição da Arquitetura das Redes e Compilação dos Modelos

# %%
i = Input(x_train.shape[1:], name="entrada")
a = Flatten(name="achatamento")(i)
a = Dense(512, activation = 'relu', name="densa1")(a)
a = Dropout(0.4, name="reducao1")(a)
a = Dense(512, activation = 'relu', name="densa2")(a)
a = Dropout(0.3, name="reducao2")(a)
a = Dense(512, activation = 'relu', name="densa3")(a)
a = Dropout(0.1, name="reducao3")(a)
a = Dense(1, activation = 'sigmoid', name="previsao")(a)

model_NN = Model(i,a, name='NN')

model_NN.compile(optimizer = 'SGD',
                 loss = "binary_crossentropy",
                 metrics = ["accuracy"])

# %%
i = Input(x_train.shape[1:], name="entrada")
b = Conv2D(32, (3,3), activation ='relu', padding = 'same', name="convolucao2d1")(i)
b = BatchNormalization(name="normalizacao1")(b)
b = Conv2D(32, (3,3), activation ='relu', padding = 'same', name="convolucao2d2")(b)
b = BatchNormalization(name="normalizacao2")(b)
b = MaxPooling2D(2,2, name="acumulacao1")(b)
b = Conv2D(64, (3,3), activation ='relu', padding = 'same', name="convolucao2d3")(b)
b = BatchNormalization(name="normalizacao3")(b)
b = Conv2D(64, (3,3), activation ='relu', padding = 'same', name="convolucao2d4")(b)
b = BatchNormalization(name="normalizacao4")(b)
b = MaxPooling2D(2,2, name="acumulacao2")(b)
b = Conv2D(128, (3,3), activation ='relu', padding = 'same', name="convolucao2d5")(b)
b = BatchNormalization(name="normalizacao5")(b)
b = Conv2D(128, (3,3), activation ='relu', padding = 'same', name="convolucao2d6")(b)
b = BatchNormalization(name="normalizacao6")(b)
b = MaxPooling2D(2,2, name="acumulacao3")(b)
b = Conv2D(256, (3,3), activation ='relu', padding = 'same', name="convolucao2d7")(b)
b = BatchNormalization(name="normalizacao7")(b)
b = Conv2D(256, (3,3), activation ='relu', padding = 'same', name="convolucao2d8")(b)
b = BatchNormalization(name="normalizacao8")(b)
b = MaxPooling2D(2,2, name="acumulacao4")(b)
b = Flatten(name="achatamento")(b)
b = Dense(512, activation = 'relu', name="densa1")(b)
b = Dropout(0.4, name="reducao1")(b)
b = Dense(512, activation = 'relu', name="densa2")(b)
b = Dropout(0.3, name="reducao2")(b)
b = Dense(512, activation = 'relu', name="densa3")(b)
b = Dropout(0.1, name="reducao3")(b)
b = Dense(1, activation = 'sigmoid', name="previsao")(b)

model_CNN = Model(i, b, name='CNN')

model_CNN.compile(optimizer = 'SGD',
                  loss = "binary_crossentropy",
                  metrics = ["accuracy"])

# %% [markdown]
# ## Visualizando a Arquitetura dos Modelos
# ### Rede Neural Simples

# %%
model_NN.summary()
# Out:
# Model: "NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# entrada (InputLayer)         [(None, 256, 256, 1)]     0
# _________________________________________________________________
# achatamento (Flatten)        (None, 65536)             0
# _________________________________________________________________
# densa1 (Dense)               (None, 512)               33554944
# _________________________________________________________________
# reducao1 (Dropout)           (None, 512)               0
# _________________________________________________________________
# densa2 (Dense)               (None, 512)               262656
# _________________________________________________________________
# reducao2 (Dropout)           (None, 512)               0
# _________________________________________________________________
# densa3 (Dense)               (None, 512)               262656
# _________________________________________________________________
# reducao3 (Dropout)           (None, 512)               0
# _________________________________________________________________
# previsao (Dense)             (None, 1)                 513
# =================================================================
# Total params: 34,080,769
# Trainable params: 34,080,769
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Rede Neural com Convoluções

# %%
model_CNN.summary()
# Out:
# Model: "CNN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# entrada (InputLayer)         [(None, 256, 256, 1)]     0
# _________________________________________________________________
# convolucao2d1 (Conv2D)       (None, 256, 256, 32)      320
# _________________________________________________________________
# normalizacao1 (BatchNormaliz (None, 256, 256, 32)      128
# _________________________________________________________________
# convolucao2d2 (Conv2D)       (None, 256, 256, 32)      9248
# _________________________________________________________________
# normalizacao2 (BatchNormaliz (None, 256, 256, 32)      128
# _________________________________________________________________
# acumulacao1 (MaxPooling2D)   (None, 128, 128, 32)      0
# _________________________________________________________________
# convolucao2d3 (Conv2D)       (None, 128, 128, 64)      18496
# _________________________________________________________________
# normalizacao3 (BatchNormaliz (None, 128, 128, 64)      256
# _________________________________________________________________
# convolucao2d4 (Conv2D)       (None, 128, 128, 64)      36928
# _________________________________________________________________
# normalizacao4 (BatchNormaliz (None, 128, 128, 64)      256
# _________________________________________________________________
# acumulacao2 (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# convolucao2d5 (Conv2D)       (None, 64, 64, 128)       73856
# _________________________________________________________________
# normalizacao5 (BatchNormaliz (None, 64, 64, 128)       512
# _________________________________________________________________
# convolucao2d6 (Conv2D)       (None, 64, 64, 128)       147584
# _________________________________________________________________
# normalizacao6 (BatchNormaliz (None, 64, 64, 128)       512
# _________________________________________________________________
# acumulacao3 (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# convolucao2d7 (Conv2D)       (None, 32, 32, 256)       295168
# _________________________________________________________________
# normalizacao7 (BatchNormaliz (None, 32, 32, 256)       1024
# _________________________________________________________________
# convolucao2d8 (Conv2D)       (None, 32, 32, 256)       590080
# _________________________________________________________________
# normalizacao8 (BatchNormaliz (None, 32, 32, 256)       1024
# _________________________________________________________________
# acumulacao4 (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# achatamento (Flatten)        (None, 65536)             0
# _________________________________________________________________
# densa1 (Dense)               (None, 512)               33554944
# _________________________________________________________________
# reducao1 (Dropout)           (None, 512)               0
# _________________________________________________________________
# densa2 (Dense)               (None, 512)               262656
# _________________________________________________________________
# reducao2 (Dropout)           (None, 512)               0
# _________________________________________________________________
# densa3 (Dense)               (None, 512)               262656
# _________________________________________________________________
# reducao3 (Dropout)           (None, 512)               0
# _________________________________________________________________
# previsao (Dense)             (None, 1)                 513
# =================================================================
# Total params: 35,256,289
# Trainable params: 35,254,369
# Non-trainable params: 1,920
# _________________________________________________________________

# %% [markdown]
# ## Data Augmentation

# %%
batch_size = 32

train_gen = ImageDataGenerator(rotation_range = 10,
                               horizontal_flip = True,
                               width_shift_range = 0.1,
                               height_shift_range = 0.1,
                               rescale = 1.,
                               zoom_range = 0.2,
                               fill_mode = 'nearest',
                               cval = 0)

train_generator_NN = train_gen.flow(x_train, y_train, batch_size)
train_generator_CNN = train_gen.flow(x_train, y_train, batch_size)

steps_per_epoch = x_train.shape[0] // batch_size

checkpoint_NN = ModelCheckpoint('model_NN.h5', 
                                monitor = 'val_loss', 
                                verbose = 0, 
                                save_best_only = True, 
                                mode = 'auto')

checkpoint_CNN = ModelCheckpoint('model_CNN.h5', 
                                 monitor = 'val_loss', 
                                 verbose = 0, 
                                 save_best_only = True, 
                                 mode = 'auto')

# %% [markdown]
# ## Treinamento dos Modelos

# %%
epochs = 150 # Reduce number of epochs for testing purposes

history_NN = model_NN.fit(train_generator_NN, 
                          validation_data = (x_test, y_test), 
                          steps_per_epoch = steps_per_epoch, 
                          epochs = epochs,
                          callbacks = [checkpoint_NN],
                          verbose = 2)

history_CNN = model_CNN.fit(train_generator_CNN, 
                            validation_data = (x_test, y_test), 
                            steps_per_epoch = steps_per_epoch, 
                            epochs = epochs,
                            callbacks = [checkpoint_CNN],
                            verbose = 2)
# Out:
# Train for 34 steps, validate on 276 samples
# Epoch 1/150
# 34/34 - 6s - loss: 0.8025 - accuracy: 0.5300 - val_loss: 0.6972 - val_accuracy: 0.5362
# Epoch 2/150
# 34/34 - 6s - loss: 0.7117 - accuracy: 0.5478 - val_loss: 0.6211 - val_accuracy: 0.7029
# Epoch 3/150
# 34/34 - 5s - loss: 0.6441 - accuracy: 0.6367 - val_loss: 0.6746 - val_accuracy: 0.5109
# Epoch 4/150
# 34/34 - 6s - loss: 0.6485 - accuracy: 0.6086 - val_loss: 0.6197 - val_accuracy: 0.6594
# Epoch 5/150
# 34/34 - 5s - loss: 0.6281 - accuracy: 0.6489 - val_loss: 0.5597 - val_accuracy: 0.7065
# Epoch 6/150
# 34/34 - 6s - loss: 0.6053 - accuracy: 0.6498 - val_loss: 0.6373 - val_accuracy: 0.6123
# Epoch 7/150
# 34/34 - 6s - loss: 0.6192 - accuracy: 0.6610 - val_loss: 0.5624 - val_accuracy: 0.6594
# Epoch 8/150
# 34/34 - 6s - loss: 0.5916 - accuracy: 0.6657 - val_loss: 0.5214 - val_accuracy: 0.7283
# Epoch 9/150
# 34/34 - 6s - loss: 0.5926 - accuracy: 0.6657 - val_loss: 0.5200 - val_accuracy: 0.7500
# Epoch 10/150
# 34/34 - 6s - loss: 0.5832 - accuracy: 0.6845 - val_loss: 0.5140 - val_accuracy: 0.7101
# Epoch 11/150
# 34/34 - 6s - loss: 0.5621 - accuracy: 0.7088 - val_loss: 0.5063 - val_accuracy: 0.7862
# Epoch 12/150
# 34/34 - 6s - loss: 0.5764 - accuracy: 0.6835 - val_loss: 0.5047 - val_accuracy: 0.7065
# Epoch 13/150
# 34/34 - 6s - loss: 0.5373 - accuracy: 0.7219 - val_loss: 0.4699 - val_accuracy: 0.7790
# Epoch 14/150
# 34/34 - 5s - loss: 0.5580 - accuracy: 0.7088 - val_loss: 0.4703 - val_accuracy: 0.8043
# Epoch 15/150
# 34/34 - 5s - loss: 0.5456 - accuracy: 0.7079 - val_loss: 0.4768 - val_accuracy: 0.8188
# Epoch 16/150
# 34/34 - 6s - loss: 0.5667 - accuracy: 0.7022 - val_loss: 0.4427 - val_accuracy: 0.7899
# Epoch 17/150
# 34/34 - 5s - loss: 0.5195 - accuracy: 0.7350 - val_loss: 0.4550 - val_accuracy: 0.8116
# Epoch 18/150
# 34/34 - 6s - loss: 0.5411 - accuracy: 0.7107 - val_loss: 0.4639 - val_accuracy: 0.7971
# Epoch 19/150
# 34/34 - 6s - loss: 0.5479 - accuracy: 0.7060 - val_loss: 0.4323 - val_accuracy: 0.8116
# Epoch 20/150
# 34/34 - 5s - loss: 0.5139 - accuracy: 0.7417 - val_loss: 0.4429 - val_accuracy: 0.8297
# Epoch 21/150
# 34/34 - 5s - loss: 0.5267 - accuracy: 0.7369 - val_loss: 0.4735 - val_accuracy: 0.8043
# Epoch 22/150
# 34/34 - 6s - loss: 0.5220 - accuracy: 0.7350 - val_loss: 0.4289 - val_accuracy: 0.8333
# Epoch 23/150
# 34/34 - 5s - loss: 0.5336 - accuracy: 0.7434 - val_loss: 0.4357 - val_accuracy: 0.7790
# Epoch 24/150
# 34/34 - 6s - loss: 0.5134 - accuracy: 0.7481 - val_loss: 0.4165 - val_accuracy: 0.8188
# Epoch 25/150
# 34/34 - 6s - loss: 0.5373 - accuracy: 0.7285 - val_loss: 0.4083 - val_accuracy: 0.8080
# Epoch 26/150
# 34/34 - 6s - loss: 0.5161 - accuracy: 0.7425 - val_loss: 0.4043 - val_accuracy: 0.8297
# Epoch 27/150
# 34/34 - 6s - loss: 0.4923 - accuracy: 0.7575 - val_loss: 0.4041 - val_accuracy: 0.8442
# Epoch 28/150
# 34/34 - 6s - loss: 0.5123 - accuracy: 0.7369 - val_loss: 0.3927 - val_accuracy: 0.8297
# Epoch 29/150
# 34/34 - 6s - loss: 0.4833 - accuracy: 0.7566 - val_loss: 0.3870 - val_accuracy: 0.8152
# Epoch 30/150
# 34/34 - 6s - loss: 0.5025 - accuracy: 0.7556 - val_loss: 0.4412 - val_accuracy: 0.8225
# Epoch 31/150
# 34/34 - 5s - loss: 0.4794 - accuracy: 0.7734 - val_loss: 0.3666 - val_accuracy: 0.8514
# Epoch 32/150
# 34/34 - 5s - loss: 0.4743 - accuracy: 0.7846 - val_loss: 0.3700 - val_accuracy: 0.8297
# Epoch 33/150
# 34/34 - 5s - loss: 0.4868 - accuracy: 0.7594 - val_loss: 0.4300 - val_accuracy: 0.8007
# Epoch 34/150
# 34/34 - 5s - loss: 0.4775 - accuracy: 0.7650 - val_loss: 0.4479 - val_accuracy: 0.7283
# Epoch 35/150
# 34/34 - 5s - loss: 0.4738 - accuracy: 0.7734 - val_loss: 0.3868 - val_accuracy: 0.8406
# Epoch 36/150
# 34/34 - 6s - loss: 0.5048 - accuracy: 0.7650 - val_loss: 0.3902 - val_accuracy: 0.8043
# Epoch 37/150
# 34/34 - 5s - loss: 0.4673 - accuracy: 0.7697 - val_loss: 0.3866 - val_accuracy: 0.8514
# Epoch 38/150
# 34/34 - 5s - loss: 0.4755 - accuracy: 0.7762 - val_loss: 0.3746 - val_accuracy: 0.8442
# Epoch 39/150
# 34/34 - 6s - loss: 0.4991 - accuracy: 0.7612 - val_loss: 0.3852 - val_accuracy: 0.8370
# Epoch 40/150
# 34/34 - 6s - loss: 0.4546 - accuracy: 0.7781 - val_loss: 0.3514 - val_accuracy: 0.8370
# Epoch 41/150
# 34/34 - 5s - loss: 0.4784 - accuracy: 0.7556 - val_loss: 0.3751 - val_accuracy: 0.8551
# Epoch 42/150
# 34/34 - 6s - loss: 0.4498 - accuracy: 0.7893 - val_loss: 0.3763 - val_accuracy: 0.8442
# Epoch 43/150
# 34/34 - 6s - loss: 0.4444 - accuracy: 0.7940 - val_loss: 0.3340 - val_accuracy: 0.8587
# Epoch 44/150
# 34/34 - 5s - loss: 0.4408 - accuracy: 0.7790 - val_loss: 0.3536 - val_accuracy: 0.8659
# Epoch 45/150
# 34/34 - 5s - loss: 0.4401 - accuracy: 0.7968 - val_loss: 0.3392 - val_accuracy: 0.8478
# Epoch 46/150
# 34/34 - 5s - loss: 0.4695 - accuracy: 0.7743 - val_loss: 0.3701 - val_accuracy: 0.8406
# Epoch 47/150
# 34/34 - 5s - loss: 0.4368 - accuracy: 0.7856 - val_loss: 0.3492 - val_accuracy: 0.8478
# Epoch 48/150
# 34/34 - 6s - loss: 0.4143 - accuracy: 0.8109 - val_loss: 0.3307 - val_accuracy: 0.8587
# Epoch 49/150
# 34/34 - 5s - loss: 0.4556 - accuracy: 0.7856 - val_loss: 0.3576 - val_accuracy: 0.8478
# Epoch 50/150
# 34/34 - 6s - loss: 0.4489 - accuracy: 0.7949 - val_loss: 0.3609 - val_accuracy: 0.8442
# Epoch 51/150
# 34/34 - 5s - loss: 0.4362 - accuracy: 0.8052 - val_loss: 0.3706 - val_accuracy: 0.8478
# Epoch 52/150
# 34/34 - 5s - loss: 0.4296 - accuracy: 0.7959 - val_loss: 0.3484 - val_accuracy: 0.8333
# Epoch 53/150
# 34/34 - 5s - loss: 0.4242 - accuracy: 0.7968 - val_loss: 0.3634 - val_accuracy: 0.8080
# Epoch 54/150
# 34/34 - 6s - loss: 0.4266 - accuracy: 0.8015 - val_loss: 0.3271 - val_accuracy: 0.8841
# Epoch 55/150
# 34/34 - 5s - loss: 0.4278 - accuracy: 0.7940 - val_loss: 0.4179 - val_accuracy: 0.8261
# Epoch 56/150
# 34/34 - 5s - loss: 0.4265 - accuracy: 0.7949 - val_loss: 0.3519 - val_accuracy: 0.8696
# Epoch 57/150
# 34/34 - 5s - loss: 0.4127 - accuracy: 0.8071 - val_loss: 0.3453 - val_accuracy: 0.8261
# Epoch 58/150
# 34/34 - 5s - loss: 0.4199 - accuracy: 0.8071 - val_loss: 0.3781 - val_accuracy: 0.8659
# Epoch 59/150
# 34/34 - 5s - loss: 0.4206 - accuracy: 0.8090 - val_loss: 0.3552 - val_accuracy: 0.8442
# Epoch 60/150
# 34/34 - 5s - loss: 0.4490 - accuracy: 0.7940 - val_loss: 0.3308 - val_accuracy: 0.8623
# Epoch 61/150
# 34/34 - 6s - loss: 0.3974 - accuracy: 0.8249 - val_loss: 0.3256 - val_accuracy: 0.8406
# Epoch 62/150
# 34/34 - 6s - loss: 0.4083 - accuracy: 0.8146 - val_loss: 0.3422 - val_accuracy: 0.8623
# Epoch 63/150
# 34/34 - 5s - loss: 0.4356 - accuracy: 0.7903 - val_loss: 0.3390 - val_accuracy: 0.8732
# Epoch 64/150
# 34/34 - 6s - loss: 0.4171 - accuracy: 0.8006 - val_loss: 0.3518 - val_accuracy: 0.8442
# Epoch 65/150
# 34/34 - 6s - loss: 0.4168 - accuracy: 0.8090 - val_loss: 0.3193 - val_accuracy: 0.8732
# Epoch 66/150
# 34/34 - 5s - loss: 0.4152 - accuracy: 0.8155 - val_loss: 0.3789 - val_accuracy: 0.8442
# Epoch 67/150
# 34/34 - 5s - loss: 0.3981 - accuracy: 0.8081 - val_loss: 0.3210 - val_accuracy: 0.8877
# Epoch 68/150
# 34/34 - 6s - loss: 0.4130 - accuracy: 0.8071 - val_loss: 0.3169 - val_accuracy: 0.8768
# Epoch 69/150
# 34/34 - 5s - loss: 0.4213 - accuracy: 0.8090 - val_loss: 0.3098 - val_accuracy: 0.8768
# Epoch 70/150
# 34/34 - 5s - loss: 0.4145 - accuracy: 0.8212 - val_loss: 0.3261 - val_accuracy: 0.8768
# Epoch 71/150
# 34/34 - 6s - loss: 0.4120 - accuracy: 0.8097 - val_loss: 0.3207 - val_accuracy: 0.8587
# Epoch 72/150
# 34/34 - 5s - loss: 0.3900 - accuracy: 0.8287 - val_loss: 0.3183 - val_accuracy: 0.8804
# Epoch 73/150
# 34/34 - 6s - loss: 0.3824 - accuracy: 0.8361 - val_loss: 0.3074 - val_accuracy: 0.8768
# Epoch 74/150
# 34/34 - 6s - loss: 0.3926 - accuracy: 0.8258 - val_loss: 0.3029 - val_accuracy: 0.8732
# Epoch 75/150
# 34/34 - 5s - loss: 0.4219 - accuracy: 0.8081 - val_loss: 0.3491 - val_accuracy: 0.8841
# Epoch 76/150
# 34/34 - 5s - loss: 0.3644 - accuracy: 0.8447 - val_loss: 0.3056 - val_accuracy: 0.8913
# Epoch 77/150
# 34/34 - 6s - loss: 0.3947 - accuracy: 0.8249 - val_loss: 0.2915 - val_accuracy: 0.8841
# Epoch 78/150
# 34/34 - 5s - loss: 0.3695 - accuracy: 0.8399 - val_loss: 0.3768 - val_accuracy: 0.8406
# Epoch 79/150
# 34/34 - 5s - loss: 0.4033 - accuracy: 0.8155 - val_loss: 0.3235 - val_accuracy: 0.8841
# Epoch 80/150
# 34/34 - 5s - loss: 0.3948 - accuracy: 0.8165 - val_loss: 0.2986 - val_accuracy: 0.8696
# Epoch 81/150
# 34/34 - 5s - loss: 0.3877 - accuracy: 0.8277 - val_loss: 0.3621 - val_accuracy: 0.8732
# Epoch 82/150
# 34/34 - 5s - loss: 0.4007 - accuracy: 0.8263 - val_loss: 0.3156 - val_accuracy: 0.9058
# Epoch 83/150
# 34/34 - 6s - loss: 0.3785 - accuracy: 0.8240 - val_loss: 0.3462 - val_accuracy: 0.8804
# Epoch 84/150
# 34/34 - 5s - loss: 0.3773 - accuracy: 0.8221 - val_loss: 0.3364 - val_accuracy: 0.8841
# Epoch 85/150
# 34/34 - 5s - loss: 0.3994 - accuracy: 0.8137 - val_loss: 0.3169 - val_accuracy: 0.8804
# Epoch 86/150
# 34/34 - 5s - loss: 0.3751 - accuracy: 0.8221 - val_loss: 0.2894 - val_accuracy: 0.8732
# Epoch 87/150
# 34/34 - 5s - loss: 0.3642 - accuracy: 0.8268 - val_loss: 0.3152 - val_accuracy: 0.8841
# Epoch 88/150
# 34/34 - 6s - loss: 0.3597 - accuracy: 0.8399 - val_loss: 0.2702 - val_accuracy: 0.8913
# Epoch 89/150
# 34/34 - 5s - loss: 0.3616 - accuracy: 0.8474 - val_loss: 0.2812 - val_accuracy: 0.8804
# Epoch 90/150
# 34/34 - 5s - loss: 0.3734 - accuracy: 0.8193 - val_loss: 0.3064 - val_accuracy: 0.8949
# Epoch 91/150
# 34/34 - 5s - loss: 0.3716 - accuracy: 0.8230 - val_loss: 0.2880 - val_accuracy: 0.9094
# Epoch 92/150
# 34/34 - 5s - loss: 0.3877 - accuracy: 0.8081 - val_loss: 0.2853 - val_accuracy: 0.9022
# Epoch 93/150
# 34/34 - 5s - loss: 0.3834 - accuracy: 0.8371 - val_loss: 0.3202 - val_accuracy: 0.8913
# Epoch 94/150
# 34/34 - 5s - loss: 0.3528 - accuracy: 0.8436 - val_loss: 0.3282 - val_accuracy: 0.9022
# Epoch 95/150
# 34/34 - 6s - loss: 0.3499 - accuracy: 0.8427 - val_loss: 0.3262 - val_accuracy: 0.8877
# Epoch 96/150
# 34/34 - 5s - loss: 0.3906 - accuracy: 0.8315 - val_loss: 0.3270 - val_accuracy: 0.8659
# Epoch 97/150
# 34/34 - 5s - loss: 0.3673 - accuracy: 0.8268 - val_loss: 0.3431 - val_accuracy: 0.8841
# Epoch 98/150
# 34/34 - 5s - loss: 0.3821 - accuracy: 0.8230 - val_loss: 0.3347 - val_accuracy: 0.8913
# Epoch 99/150
# 34/34 - 5s - loss: 0.3709 - accuracy: 0.8380 - val_loss: 0.3385 - val_accuracy: 0.8732
# Epoch 100/150
# 34/34 - 5s - loss: 0.3722 - accuracy: 0.8371 - val_loss: 0.3864 - val_accuracy: 0.8225
# Epoch 101/150
# 34/34 - 6s - loss: 0.3784 - accuracy: 0.8249 - val_loss: 0.2650 - val_accuracy: 0.9239
# Epoch 102/150
# 34/34 - 5s - loss: 0.3691 - accuracy: 0.8408 - val_loss: 0.3206 - val_accuracy: 0.8804
# Epoch 103/150
# 34/34 - 5s - loss: 0.3581 - accuracy: 0.8511 - val_loss: 0.3010 - val_accuracy: 0.8913
# Epoch 104/150
# 34/34 - 5s - loss: 0.3451 - accuracy: 0.8539 - val_loss: 0.3546 - val_accuracy: 0.8551
# Epoch 105/150
# 34/34 - 5s - loss: 0.3607 - accuracy: 0.8380 - val_loss: 0.3201 - val_accuracy: 0.8841
# Epoch 106/150
# 34/34 - 6s - loss: 0.3583 - accuracy: 0.8427 - val_loss: 0.3804 - val_accuracy: 0.8370
# Epoch 107/150
# 34/34 - 6s - loss: 0.3807 - accuracy: 0.8240 - val_loss: 0.3028 - val_accuracy: 0.8804
# Epoch 108/150
# 34/34 - 5s - loss: 0.3471 - accuracy: 0.8521 - val_loss: 0.3053 - val_accuracy: 0.8841
# Epoch 109/150
# 34/34 - 5s - loss: 0.3821 - accuracy: 0.8418 - val_loss: 0.3070 - val_accuracy: 0.8841
# Epoch 110/150
# 34/34 - 5s - loss: 0.3543 - accuracy: 0.8390 - val_loss: 0.3272 - val_accuracy: 0.8804
# Epoch 111/150
# 34/34 - 5s - loss: 0.3804 - accuracy: 0.8324 - val_loss: 0.3182 - val_accuracy: 0.9058
# Epoch 112/150
# 34/34 - 5s - loss: 0.3789 - accuracy: 0.8268 - val_loss: 0.3102 - val_accuracy: 0.8986
# Epoch 113/150
# 34/34 - 5s - loss: 0.3648 - accuracy: 0.8324 - val_loss: 0.3048 - val_accuracy: 0.8986
# Epoch 114/150
# 34/34 - 5s - loss: 0.3629 - accuracy: 0.8427 - val_loss: 0.3129 - val_accuracy: 0.8877
# Epoch 115/150
# 34/34 - 5s - loss: 0.3670 - accuracy: 0.8277 - val_loss: 0.4043 - val_accuracy: 0.8261
# Epoch 116/150
# 34/34 - 5s - loss: 0.3507 - accuracy: 0.8371 - val_loss: 0.3526 - val_accuracy: 0.8732
# Epoch 117/150
# 34/34 - 5s - loss: 0.3456 - accuracy: 0.8474 - val_loss: 0.3078 - val_accuracy: 0.8913
# Epoch 118/150
# 34/34 - 6s - loss: 0.3916 - accuracy: 0.8240 - val_loss: 0.3931 - val_accuracy: 0.8261
# Epoch 119/150
# 34/34 - 5s - loss: 0.3355 - accuracy: 0.8446 - val_loss: 0.3323 - val_accuracy: 0.8768
# Epoch 120/150
# 34/34 - 5s - loss: 0.3493 - accuracy: 0.8380 - val_loss: 0.3087 - val_accuracy: 0.8804
# Epoch 121/150
# 34/34 - 5s - loss: 0.3362 - accuracy: 0.8577 - val_loss: 0.3309 - val_accuracy: 0.8623
# Epoch 122/150
# 34/34 - 5s - loss: 0.3527 - accuracy: 0.8493 - val_loss: 0.3142 - val_accuracy: 0.8804
# Epoch 123/150
# 34/34 - 5s - loss: 0.3435 - accuracy: 0.8474 - val_loss: 0.3260 - val_accuracy: 0.8877
# Epoch 124/150
# 34/34 - 5s - loss: 0.3621 - accuracy: 0.8380 - val_loss: 0.2900 - val_accuracy: 0.9130
# Epoch 125/150
# 34/34 - 5s - loss: 0.3358 - accuracy: 0.8558 - val_loss: 0.3134 - val_accuracy: 0.8659
# Epoch 126/150
# 34/34 - 5s - loss: 0.3337 - accuracy: 0.8427 - val_loss: 0.2874 - val_accuracy: 0.9094
# Epoch 127/150
# 34/34 - 5s - loss: 0.3466 - accuracy: 0.8399 - val_loss: 0.3748 - val_accuracy: 0.8297
# Epoch 128/150
# 34/34 - 6s - loss: 0.3492 - accuracy: 0.8455 - val_loss: 0.3133 - val_accuracy: 0.8623
# Epoch 129/150
# 34/34 - 6s - loss: 0.3558 - accuracy: 0.8371 - val_loss: 0.3775 - val_accuracy: 0.8442
# Epoch 130/150
# 34/34 - 6s - loss: 0.3277 - accuracy: 0.8567 - val_loss: 0.3029 - val_accuracy: 0.8623
# Epoch 131/150
# 34/34 - 5s - loss: 0.3355 - accuracy: 0.8530 - val_loss: 0.3099 - val_accuracy: 0.8913
# Epoch 132/150
# 34/34 - 5s - loss: 0.3679 - accuracy: 0.8258 - val_loss: 0.3203 - val_accuracy: 0.8768
# Epoch 133/150
# 34/34 - 5s - loss: 0.3312 - accuracy: 0.8549 - val_loss: 0.3126 - val_accuracy: 0.8732
# Epoch 134/150
# 34/34 - 5s - loss: 0.3263 - accuracy: 0.8493 - val_loss: 0.3184 - val_accuracy: 0.8913
# Epoch 135/150
# 34/34 - 5s - loss: 0.3436 - accuracy: 0.8474 - val_loss: 0.3361 - val_accuracy: 0.8587
# Epoch 136/150
# 34/34 - 5s - loss: 0.3272 - accuracy: 0.8567 - val_loss: 0.4169 - val_accuracy: 0.8080
# Epoch 137/150
# 34/34 - 5s - loss: 0.3359 - accuracy: 0.8558 - val_loss: 0.3200 - val_accuracy: 0.8478
# Epoch 138/150
# 34/34 - 5s - loss: 0.3461 - accuracy: 0.8493 - val_loss: 0.3711 - val_accuracy: 0.8225
# Epoch 139/150
# 34/34 - 5s - loss: 0.3353 - accuracy: 0.8446 - val_loss: 0.3305 - val_accuracy: 0.8659
# Epoch 140/150
# 34/34 - 6s - loss: 0.3111 - accuracy: 0.8558 - val_loss: 0.2948 - val_accuracy: 0.8768
# Epoch 141/150
# 34/34 - 6s - loss: 0.3406 - accuracy: 0.8502 - val_loss: 0.3343 - val_accuracy: 0.8514
# Epoch 142/150
# 34/34 - 5s - loss: 0.3269 - accuracy: 0.8577 - val_loss: 0.3171 - val_accuracy: 0.8804
# Epoch 143/150
# 34/34 - 5s - loss: 0.3386 - accuracy: 0.8464 - val_loss: 0.2867 - val_accuracy: 0.8913
# Epoch 144/150
# 34/34 - 5s - loss: 0.3383 - accuracy: 0.8502 - val_loss: 0.3370 - val_accuracy: 0.8696
# Epoch 145/150
# 34/34 - 5s - loss: 0.3375 - accuracy: 0.8474 - val_loss: 0.3192 - val_accuracy: 0.8732
# Epoch 146/150
# 34/34 - 5s - loss: 0.3182 - accuracy: 0.8642 - val_loss: 0.2942 - val_accuracy: 0.8804
# Epoch 147/150
# 34/34 - 5s - loss: 0.3346 - accuracy: 0.8567 - val_loss: 0.3363 - val_accuracy: 0.8659
# Epoch 148/150
# 34/34 - 5s - loss: 0.3351 - accuracy: 0.8577 - val_loss: 0.3651 - val_accuracy: 0.8370
# Epoch 149/150
# 34/34 - 5s - loss: 0.3596 - accuracy: 0.8408 - val_loss: 0.3412 - val_accuracy: 0.8623
# Epoch 150/150
# 34/34 - 5s - loss: 0.3444 - accuracy: 0.8511 - val_loss: 0.3859 - val_accuracy: 0.8406
# Train for 34 steps, validate on 276 samples
# Epoch 1/150
# 34/34 - 14s - loss: 0.7735 - accuracy: 0.6901 - val_loss: 0.6869 - val_accuracy: 0.5000
# Epoch 2/150
# 34/34 - 7s - loss: 0.2890 - accuracy: 0.8848 - val_loss: 0.7926 - val_accuracy: 0.5000
# Epoch 3/150
# 34/34 - 7s - loss: 0.1997 - accuracy: 0.9288 - val_loss: 0.8113 - val_accuracy: 0.5000
# Epoch 4/150
# 34/34 - 7s - loss: 0.2046 - accuracy: 0.9148 - val_loss: 1.3675 - val_accuracy: 0.5000
# Epoch 5/150
# 34/34 - 7s - loss: 0.1717 - accuracy: 0.9382 - val_loss: 1.3047 - val_accuracy: 0.5000
# Epoch 6/150
# 34/34 - 7s - loss: 0.1533 - accuracy: 0.9457 - val_loss: 1.6637 - val_accuracy: 0.5000
# Epoch 7/150
# 34/34 - 7s - loss: 0.1201 - accuracy: 0.9541 - val_loss: 2.7948 - val_accuracy: 0.5000
# Epoch 8/150
# 34/34 - 8s - loss: 0.1047 - accuracy: 0.9597 - val_loss: 2.4684 - val_accuracy: 0.5000
# Epoch 9/150
# 34/34 - 8s - loss: 0.0757 - accuracy: 0.9644 - val_loss: 2.8772 - val_accuracy: 0.5000
# Epoch 10/150
# 34/34 - 7s - loss: 0.1029 - accuracy: 0.9682 - val_loss: 3.1045 - val_accuracy: 0.5000
# Epoch 11/150
# 34/34 - 7s - loss: 0.0931 - accuracy: 0.9710 - val_loss: 3.1610 - val_accuracy: 0.5000
# Epoch 12/150
# 34/34 - 7s - loss: 0.0590 - accuracy: 0.9766 - val_loss: 2.9873 - val_accuracy: 0.5000
# Epoch 13/150
# 34/34 - 8s - loss: 0.0670 - accuracy: 0.9775 - val_loss: 3.2612 - val_accuracy: 0.5000
# Epoch 14/150
# 34/34 - 7s - loss: 0.0373 - accuracy: 0.9878 - val_loss: 3.0207 - val_accuracy: 0.5000
# Epoch 15/150
# 34/34 - 7s - loss: 0.0332 - accuracy: 0.9878 - val_loss: 4.4757 - val_accuracy: 0.5000
# Epoch 16/150
# 34/34 - 8s - loss: 0.0517 - accuracy: 0.9785 - val_loss: 0.1440 - val_accuracy: 0.9529
# Epoch 17/150
# 34/34 - 8s - loss: 0.0494 - accuracy: 0.9844 - val_loss: 0.1355 - val_accuracy: 0.9601
# Epoch 18/150
# 34/34 - 7s - loss: 0.0449 - accuracy: 0.9860 - val_loss: 0.9503 - val_accuracy: 0.6993
# Epoch 19/150
# 34/34 - 8s - loss: 0.0405 - accuracy: 0.9878 - val_loss: 0.0886 - val_accuracy: 0.9674
# Epoch 20/150
# 34/34 - 7s - loss: 0.0453 - accuracy: 0.9844 - val_loss: 0.1214 - val_accuracy: 0.9529
# Epoch 21/150
# 34/34 - 7s - loss: 0.0226 - accuracy: 0.9916 - val_loss: 0.2867 - val_accuracy: 0.8841
# Epoch 22/150
# 34/34 - 7s - loss: 0.0212 - accuracy: 0.9944 - val_loss: 0.3904 - val_accuracy: 0.8841
# Epoch 23/150
# 34/34 - 8s - loss: 0.0201 - accuracy: 0.9936 - val_loss: 0.0865 - val_accuracy: 0.9601
# Epoch 24/150
# 34/34 - 8s - loss: 0.0269 - accuracy: 0.9878 - val_loss: 0.1220 - val_accuracy: 0.9529
# Epoch 25/150
# 34/34 - 7s - loss: 0.0341 - accuracy: 0.9860 - val_loss: 0.7642 - val_accuracy: 0.7464
# Epoch 26/150
# 34/34 - 7s - loss: 0.0108 - accuracy: 0.9954 - val_loss: 0.0949 - val_accuracy: 0.9746
# Epoch 27/150
# 34/34 - 7s - loss: 0.0237 - accuracy: 0.9925 - val_loss: 0.3172 - val_accuracy: 0.9167
# Epoch 28/150
# 34/34 - 7s - loss: 0.0204 - accuracy: 0.9953 - val_loss: 2.7265 - val_accuracy: 0.6232
# Epoch 29/150
# 34/34 - 7s - loss: 0.0206 - accuracy: 0.9916 - val_loss: 0.1149 - val_accuracy: 0.9855
# Epoch 30/150
# 34/34 - 7s - loss: 0.0155 - accuracy: 0.9953 - val_loss: 0.1150 - val_accuracy: 0.9783
# Epoch 31/150
# 34/34 - 7s - loss: 0.0273 - accuracy: 0.9916 - val_loss: 0.1427 - val_accuracy: 0.9529
# Epoch 32/150
# 34/34 - 7s - loss: 0.0127 - accuracy: 0.9963 - val_loss: 0.1110 - val_accuracy: 0.9819
# Epoch 33/150
# 34/34 - 8s - loss: 0.0245 - accuracy: 0.9916 - val_loss: 0.1631 - val_accuracy: 0.9783
# Epoch 34/150
# 34/34 - 7s - loss: 0.0173 - accuracy: 0.9953 - val_loss: 0.1711 - val_accuracy: 0.9746
# Epoch 35/150
# 34/34 - 7s - loss: 0.0169 - accuracy: 0.9934 - val_loss: 0.1134 - val_accuracy: 0.9855
# Epoch 36/150
# 34/34 - 7s - loss: 0.0210 - accuracy: 0.9925 - val_loss: 0.6096 - val_accuracy: 0.8587
# Epoch 37/150
# 34/34 - 7s - loss: 0.0171 - accuracy: 0.9925 - val_loss: 0.0958 - val_accuracy: 0.9746
# Epoch 38/150
# 34/34 - 7s - loss: 0.0192 - accuracy: 0.9916 - val_loss: 0.1184 - val_accuracy: 0.9746
# Epoch 39/150
# 34/34 - 7s - loss: 0.0377 - accuracy: 0.9869 - val_loss: 0.0956 - val_accuracy: 0.9855
# Epoch 40/150
# 34/34 - 7s - loss: 0.0179 - accuracy: 0.9944 - val_loss: 0.6152 - val_accuracy: 0.8080
# Epoch 41/150
# 34/34 - 8s - loss: 0.0151 - accuracy: 0.9934 - val_loss: 0.0983 - val_accuracy: 0.9710
# Epoch 42/150
# 34/34 - 7s - loss: 0.0262 - accuracy: 0.9888 - val_loss: 0.1393 - val_accuracy: 0.9565
# Epoch 43/150
# 34/34 - 7s - loss: 0.0190 - accuracy: 0.9944 - val_loss: 0.1017 - val_accuracy: 0.9746
# Epoch 44/150
# 34/34 - 7s - loss: 0.0091 - accuracy: 0.9981 - val_loss: 0.1948 - val_accuracy: 0.9348
# Epoch 45/150
# 34/34 - 8s - loss: 0.0134 - accuracy: 0.9953 - val_loss: 0.0808 - val_accuracy: 0.9783
# Epoch 46/150
# 34/34 - 7s - loss: 0.0097 - accuracy: 0.9981 - val_loss: 0.1022 - val_accuracy: 0.9855
# Epoch 47/150
# 34/34 - 7s - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.0997 - val_accuracy: 0.9819
# Epoch 48/150
# 34/34 - 7s - loss: 0.0142 - accuracy: 0.9963 - val_loss: 0.0998 - val_accuracy: 0.9819
# Epoch 49/150
# 34/34 - 8s - loss: 0.0083 - accuracy: 0.9963 - val_loss: 0.1527 - val_accuracy: 0.9638
# Epoch 50/150
# 34/34 - 8s - loss: 0.0223 - accuracy: 0.9916 - val_loss: 0.0717 - val_accuracy: 0.9819
# Epoch 51/150
# 34/34 - 7s - loss: 0.0106 - accuracy: 0.9963 - val_loss: 0.0781 - val_accuracy: 0.9891
# Epoch 52/150
# 34/34 - 7s - loss: 0.0094 - accuracy: 0.9981 - val_loss: 0.0841 - val_accuracy: 0.9855
# Epoch 53/150
# 34/34 - 7s - loss: 0.0265 - accuracy: 0.9934 - val_loss: 0.1052 - val_accuracy: 0.9855
# Epoch 54/150
# 34/34 - 7s - loss: 0.0108 - accuracy: 0.9953 - val_loss: 4.9348 - val_accuracy: 0.5652
# Epoch 55/150
# 34/34 - 7s - loss: 0.0121 - accuracy: 0.9963 - val_loss: 1.5834 - val_accuracy: 0.6993
# Epoch 56/150
# 34/34 - 7s - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.7723 - val_accuracy: 0.7899
# Epoch 57/150
# 34/34 - 7s - loss: 0.0130 - accuracy: 0.9981 - val_loss: 0.0927 - val_accuracy: 0.9819
# Epoch 58/150
# 34/34 - 7s - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.0843 - val_accuracy: 0.9819
# Epoch 59/150
# 34/34 - 7s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.2234 - val_accuracy: 0.9529
# Epoch 60/150
# 34/34 - 7s - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.0966 - val_accuracy: 0.9891
# Epoch 61/150
# 34/34 - 7s - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.0957 - val_accuracy: 0.9746
# Epoch 62/150
# 34/34 - 7s - loss: 0.0085 - accuracy: 0.9953 - val_loss: 0.1081 - val_accuracy: 0.9819
# Epoch 63/150
# 34/34 - 7s - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.0833 - val_accuracy: 0.9891
# Epoch 64/150
# 34/34 - 7s - loss: 0.0050 - accuracy: 0.9981 - val_loss: 0.0866 - val_accuracy: 0.9891
# Epoch 65/150
# 34/34 - 7s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.1776 - val_accuracy: 0.9565
# Epoch 66/150
# 34/34 - 7s - loss: 0.0121 - accuracy: 0.9963 - val_loss: 0.1199 - val_accuracy: 0.9819
# Epoch 67/150
# 34/34 - 7s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.1108 - val_accuracy: 0.9855
# Epoch 68/150
# 34/34 - 7s - loss: 0.0036 - accuracy: 0.9981 - val_loss: 0.1305 - val_accuracy: 0.9819
# Epoch 69/150
# 34/34 - 7s - loss: 0.0063 - accuracy: 0.9981 - val_loss: 0.1498 - val_accuracy: 0.9819
# Epoch 70/150
# 34/34 - 7s - loss: 0.0084 - accuracy: 0.9963 - val_loss: 0.1237 - val_accuracy: 0.9746
# Epoch 71/150
# 34/34 - 7s - loss: 0.0049 - accuracy: 0.9972 - val_loss: 0.1134 - val_accuracy: 0.9891
# Epoch 72/150
# 34/34 - 7s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.1178 - val_accuracy: 0.9855
# Epoch 73/150
# 34/34 - 7s - loss: 0.0088 - accuracy: 0.9991 - val_loss: 0.0894 - val_accuracy: 0.9928
# Epoch 74/150
# 34/34 - 7s - loss: 0.0084 - accuracy: 0.9944 - val_loss: 0.3137 - val_accuracy: 0.9384
# Epoch 75/150
# 34/34 - 7s - loss: 0.0134 - accuracy: 0.9963 - val_loss: 0.1142 - val_accuracy: 0.9783
# Epoch 76/150
# 34/34 - 7s - loss: 0.0071 - accuracy: 0.9981 - val_loss: 0.0999 - val_accuracy: 0.9855
# Epoch 77/150
# 34/34 - 7s - loss: 0.0065 - accuracy: 0.9981 - val_loss: 0.0967 - val_accuracy: 0.9855
# Epoch 78/150
# 34/34 - 7s - loss: 0.0035 - accuracy: 0.9991 - val_loss: 0.1228 - val_accuracy: 0.9819
# Epoch 79/150
# 34/34 - 7s - loss: 0.0180 - accuracy: 0.9963 - val_loss: 0.1241 - val_accuracy: 0.9855
# Epoch 80/150
# 34/34 - 7s - loss: 0.0077 - accuracy: 0.9953 - val_loss: 3.6105 - val_accuracy: 0.6051
# Epoch 81/150
# 34/34 - 7s - loss: 0.0046 - accuracy: 0.9981 - val_loss: 0.1414 - val_accuracy: 0.9855
# Epoch 82/150
# 34/34 - 7s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1295 - val_accuracy: 0.9891
# Epoch 83/150
# 34/34 - 7s - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.1755 - val_accuracy: 0.9674
# Epoch 84/150
# 34/34 - 7s - loss: 0.0041 - accuracy: 0.9991 - val_loss: 0.1154 - val_accuracy: 0.9928
# Epoch 85/150
# 34/34 - 7s - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.9782 - val_accuracy: 0.8188
# Epoch 86/150
# 34/34 - 7s - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.2267 - val_accuracy: 0.9493
# Epoch 87/150
# 34/34 - 7s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1034 - val_accuracy: 0.9928
# Epoch 88/150
# 34/34 - 7s - loss: 6.7166e-04 - accuracy: 1.0000 - val_loss: 0.1062 - val_accuracy: 0.9891
# Epoch 89/150
# 34/34 - 7s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1360 - val_accuracy: 0.9855
# Epoch 90/150
# 34/34 - 7s - loss: 0.0019 - accuracy: 0.9991 - val_loss: 0.1258 - val_accuracy: 0.9891
# Epoch 91/150
# 34/34 - 7s - loss: 0.0063 - accuracy: 0.9972 - val_loss: 0.1179 - val_accuracy: 0.9891
# Epoch 92/150
# 34/34 - 8s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1059 - val_accuracy: 0.9891
# Epoch 93/150
# 34/34 - 7s - loss: 0.0041 - accuracy: 0.9991 - val_loss: 0.1023 - val_accuracy: 0.9891
# Epoch 94/150
# 34/34 - 7s - loss: 0.0037 - accuracy: 0.9981 - val_loss: 0.9414 - val_accuracy: 0.8333
# Epoch 95/150
# 34/34 - 7s - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.4129 - val_accuracy: 0.9275
# Epoch 96/150
# 34/34 - 7s - loss: 0.0062 - accuracy: 0.9963 - val_loss: 0.1146 - val_accuracy: 0.9819
# Epoch 97/150
# 34/34 - 7s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0828 - val_accuracy: 0.9891
# Epoch 98/150
# 34/34 - 7s - loss: 0.0019 - accuracy: 0.9991 - val_loss: 0.1705 - val_accuracy: 0.9783
# Epoch 99/150
# 34/34 - 7s - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.1651 - val_accuracy: 0.9783
# Epoch 100/150
# 34/34 - 7s - loss: 0.0065 - accuracy: 0.9963 - val_loss: 1.0513 - val_accuracy: 0.8225
# Epoch 101/150
# 34/34 - 7s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2022 - val_accuracy: 0.9638
# Epoch 102/150
# 34/34 - 7s - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.1794 - val_accuracy: 0.9891
# Epoch 103/150
# 34/34 - 7s - loss: 0.0045 - accuracy: 0.9972 - val_loss: 0.5425 - val_accuracy: 0.9058
# Epoch 104/150
# 34/34 - 7s - loss: 0.0073 - accuracy: 0.9972 - val_loss: 0.4999 - val_accuracy: 0.8986
# Epoch 105/150
# 34/34 - 7s - loss: 0.0123 - accuracy: 0.9972 - val_loss: 0.1938 - val_accuracy: 0.9529
# Epoch 106/150
# 34/34 - 7s - loss: 0.0031 - accuracy: 0.9991 - val_loss: 0.4666 - val_accuracy: 0.9239
# Epoch 107/150
# 34/34 - 7s - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0988 - val_accuracy: 0.9855
# Epoch 108/150
# 34/34 - 7s - loss: 0.0029 - accuracy: 0.9991 - val_loss: 0.0904 - val_accuracy: 0.9891
# Epoch 109/150
# 34/34 - 7s - loss: 0.0083 - accuracy: 0.9981 - val_loss: 0.2492 - val_accuracy: 0.9457
# Epoch 110/150
# 34/34 - 7s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.4391 - val_accuracy: 0.9275
# Epoch 111/150
# 34/34 - 7s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0999 - val_accuracy: 0.9891
# Epoch 112/150
# 34/34 - 7s - loss: 0.0020 - accuracy: 0.9991 - val_loss: 0.1101 - val_accuracy: 0.9891
# Epoch 113/150
# 34/34 - 7s - loss: 0.0013 - accuracy: 0.9991 - val_loss: 0.1038 - val_accuracy: 0.9891
# Epoch 114/150
# 34/34 - 7s - loss: 5.6626e-04 - accuracy: 1.0000 - val_loss: 0.1220 - val_accuracy: 0.9783
# Epoch 115/150
# 34/34 - 7s - loss: 9.7959e-04 - accuracy: 1.0000 - val_loss: 0.1053 - val_accuracy: 0.9891
# Epoch 116/150
# 34/34 - 7s - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0991 - val_accuracy: 0.9891
# Epoch 117/150
# 34/34 - 7s - loss: 0.0014 - accuracy: 0.9991 - val_loss: 0.1706 - val_accuracy: 0.9674
# Epoch 118/150
# 34/34 - 8s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0801 - val_accuracy: 0.9891
# Epoch 119/150
# 34/34 - 7s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0797 - val_accuracy: 0.9819
# Epoch 120/150
# 34/34 - 7s - loss: 0.0157 - accuracy: 0.9953 - val_loss: 1.0547 - val_accuracy: 0.7681
# Epoch 121/150
# 34/34 - 7s - loss: 0.0023 - accuracy: 0.9991 - val_loss: 1.7192 - val_accuracy: 0.7464
# Epoch 122/150
# 34/34 - 7s - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.1210 - val_accuracy: 0.9891
# Epoch 123/150
# 34/34 - 7s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.1111 - val_accuracy: 0.9891
# Epoch 124/150
# 34/34 - 7s - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.1484 - val_accuracy: 0.9819
# Epoch 125/150
# 34/34 - 7s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1406 - val_accuracy: 0.9783
# Epoch 126/150
# 34/34 - 8s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.2130 - val_accuracy: 0.9638
# Epoch 127/150
# 34/34 - 7s - loss: 0.0057 - accuracy: 0.9963 - val_loss: 0.1983 - val_accuracy: 0.9783
# Epoch 128/150
# 34/34 - 7s - loss: 0.0033 - accuracy: 0.9981 - val_loss: 0.1442 - val_accuracy: 0.9855
# Epoch 129/150
# 34/34 - 7s - loss: 0.0237 - accuracy: 0.9953 - val_loss: 0.2297 - val_accuracy: 0.9710
# Epoch 130/150
# 34/34 - 7s - loss: 0.0280 - accuracy: 0.9908 - val_loss: 13.7861 - val_accuracy: 0.5543
# Epoch 131/150
# 34/34 - 7s - loss: 0.0150 - accuracy: 0.9953 - val_loss: 1.1250 - val_accuracy: 0.7609
# Epoch 132/150
# 34/34 - 7s - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.3898 - val_accuracy: 0.9348
# Epoch 133/150
# 34/34 - 7s - loss: 0.0069 - accuracy: 0.9972 - val_loss: 0.2550 - val_accuracy: 0.9601
# Epoch 134/150
# 34/34 - 7s - loss: 0.0077 - accuracy: 0.9963 - val_loss: 0.3350 - val_accuracy: 0.9565
# Epoch 135/150
# 34/34 - 7s - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.1910 - val_accuracy: 0.9710
# Epoch 136/150
# 34/34 - 7s - loss: 0.0068 - accuracy: 0.9981 - val_loss: 0.1509 - val_accuracy: 0.9746
# Epoch 137/150
# 34/34 - 7s - loss: 0.0136 - accuracy: 0.9963 - val_loss: 1.1329 - val_accuracy: 0.7935
# Epoch 138/150
# 34/34 - 7s - loss: 0.0031 - accuracy: 0.9991 - val_loss: 1.0029 - val_accuracy: 0.7899
# Epoch 139/150
# 34/34 - 7s - loss: 0.0113 - accuracy: 0.9981 - val_loss: 4.8551 - val_accuracy: 0.5580
# Epoch 140/150
# 34/34 - 7s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3139 - val_accuracy: 0.9420
# Epoch 141/150
# 34/34 - 7s - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.9891
# Epoch 142/150
# 34/34 - 7s - loss: 6.4930e-04 - accuracy: 1.0000 - val_loss: 0.1231 - val_accuracy: 0.9855
# Epoch 143/150
# 34/34 - 7s - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.1010 - val_accuracy: 0.9855
# Epoch 144/150
# 34/34 - 7s - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.1338 - val_accuracy: 0.9891
# Epoch 145/150
# 34/34 - 7s - loss: 0.0048 - accuracy: 0.9981 - val_loss: 0.2085 - val_accuracy: 0.9493
# Epoch 146/150
# 34/34 - 7s - loss: 0.0043 - accuracy: 0.9991 - val_loss: 0.0881 - val_accuracy: 0.9891
# Epoch 147/150
# 34/34 - 7s - loss: 0.0039 - accuracy: 0.9972 - val_loss: 0.3226 - val_accuracy: 0.9384
# Epoch 148/150
# 34/34 - 7s - loss: 0.0032 - accuracy: 0.9991 - val_loss: 0.1553 - val_accuracy: 0.9855
# Epoch 149/150
# 34/34 - 7s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.1033 - val_accuracy: 0.9891
# Epoch 150/150
# 34/34 - 7s - loss: 0.0028 - accuracy: 0.9981 - val_loss: 0.0932 - val_accuracy: 0.9891

# %% [markdown]
# ## Performance do Modelo

# %%
model_NN = tf.keras.models.load_model('model_NN.h5')
model_CNN = tf.keras.models.load_model('model_CNN.h5')

# %%
def plot_accuracy_hist(model_history, fig_title):

    plt.rcParams.update({'font.size': 14})

    fig = plt.figure(figsize = (16, 4))
    columns = 2
    rows = 1

    fig.suptitle(fig_title, fontsize = 20, y = 1.08)
    fig.add_subplot(rows, columns, 1)

    plt.title('Accuracy')
    plt.ylim(0.6, 1)
    
    plt.plot(model_history.history['accuracy'], 
             color='green', 
             label = 'Train Accuracy')

    plt.plot(model_history.history['val_accuracy'], 
             color='red', 
             label = 'Test Accuracy', 
             linestyle='dashed')

    plt.legend()

    fig.add_subplot(rows, columns, 2)

    plt.title('Loss')
    plt.plot(model_history.history['loss'], 
             color='green', 
             label = 'Train Loss')

    plt.plot(model_history.history['val_loss'], 
             color='red', 
             label = 'Test Loss', 
             linestyle='dashed')

    plt.legend()

    plt.show()
    
plot_accuracy_hist(history_NN, 'Neural Network')
plot_accuracy_hist(history_CNN, 'Convolutional Neural Network')

# %% [markdown]
# ### Confusion Matrix

# %%
plt.rcParams.update({'font.size': 16})

def plot_confusion_mtx(model, x_test, plot_tittle):
    pred_prob = model.predict(x_test, batch_size = 8)
    pred = np.where(pred_prob > 0.5, 1,0)

    CM = confusion_matrix(y_test, pred)

    plot_confusion_matrix(conf_mat = CM, figsize = (16, 8))
    plt.title(plot_tittle)
    plt.xticks(range(2), labels)
    plt.yticks(range(2), labels)

    plt.show()

plot_confusion_mtx(model_NN, x_test, 'Neural Network')
plot_confusion_mtx(model_CNN, x_test, 'Convolutional Neural Network')

# %% [markdown]
# ### Checking Errors

# %%
y_true = y_test
pred_prob = model_CNN.predict(x_test)
y_pred = np.where(pred_prob > 0.5, 1,0)

errors = y_pred != y_test
hits = y_pred == y_test

y_test_erros  = y_pred[errors[0:, 0]]
y_true_errors = y_true[errors[0:, 0]]
x_test_errors = x_test[errors[0:, 0]]

y_test_hits  = y_pred[hits[0:, 0]]
y_true_hits = y_true[hits[0:, 0]]
x_test_hits = x_test[hits[0:, 0]]

print('Neural Network')
print('quantidade de erros: \t' + str(len(y_test_erros)))
print('quantidade de hits: \t' + str(len(y_test_hits)))
print('Acuracia: \t' + str(len(y_test_hits) / (len(y_test_erros) + len(y_test_hits))))
# Out:
# Neural Network
# quantidade de erros: 	5
# quantidade de hits: 	271
# Acuracia: 	0.9818840579710145

# %%
plt.rcParams.update({'font.size': 12})

fig = plt.figure(figsize = (16, 12))
columns = 4
rows = 3

for i in range(1, columns * rows + 1):
    try:
        img = np.reshape(x_test_errors[i - 1], (256, 256))
        fig.add_subplot(rows, columns, i)
        plt.title('predicted: ' + str(labels[y_test_erros[i - 1][0]]) + 
                  '\ntrue label: ' + str(labels[y_true_errors[i - 1][0]]))
        plt.axis('off')
        plt.imshow(img, cmap = 'gray')
    except:
        break

plt.show()

# %% [markdown]
# ### Receiver Operating Characteristic

# %%
pred_prob_NN  = model_NN.predict(x_test, batch_size = 8)
pred_prob_CNN = model_CNN.predict(x_test, batch_size = 8)

pred_NN  = np.where(pred_prob_NN > 0.5, 1,0)
pred_CNN = np.where(pred_prob_CNN > 0.5, 1,0)

NN_fpr, NN_tpr, _ = roc_curve(y_test, pred_prob_NN)
NN_roc_auc = auc(NN_fpr, NN_tpr)

CNN_fpr, CNN_tpr, _ = roc_curve(y_test, pred_prob_CNN)
CNN_roc_auc = auc(CNN_fpr, CNN_tpr)

plt.rcParams.update({'font.size': 16})

fig = plt.figure(figsize = (8, 6))

lw = 2
plt.plot(CNN_fpr,
         CNN_tpr, 
         color = 'darkorange',
         lw = lw, 
         label = 'CNN - ROC curve (area = %0.2f)' % CNN_roc_auc)

plt.plot(NN_fpr,
         NN_tpr, 
         color = 'grey',
         lw = lw, 
         label = '  NN - ROC curve (area = %0.2f)' % NN_roc_auc)

plt.plot([0, 1], [0, 1], 
         color = 'navy', 
         lw = lw, 
         linestyle = '--')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.title('Receiver operating characteristic')
plt.legend(loc = "lower right")

plt.show()

print('Classification Report - Neural Network')
print(classification_report(y_test, pred_NN))

print('\nClassification Report - Convolutional Neural Network')
print(classification_report(y_test, pred_CNN))
# Out:
# Classification Report - Neural Network
#               precision    recall  f1-score   support
#
#            0       0.92      0.93      0.92       138
#            1       0.93      0.92      0.92       138
#
#     accuracy                           0.92       276
#    macro avg       0.92      0.92      0.92       276
# weighted avg       0.92      0.92      0.92       276
#
#
# Classification Report - Convolutional Neural Network
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       138
#            1       0.98      0.99      0.98       138
#
#     accuracy                           0.98       276
#    macro avg       0.98      0.98      0.98       276
# weighted avg       0.98      0.98      0.98       276
