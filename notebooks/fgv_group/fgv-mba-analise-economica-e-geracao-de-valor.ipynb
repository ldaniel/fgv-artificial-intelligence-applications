# %%
# %%html
# <style>
#   table {margin-left: 0 !important;}
# </style>
# Out:
# <style>
#   table {margin-left: 0 !important;}
# </style>

# %% [markdown]
# # Detecção de rostos com uso de máscara de proteção para COVID-19
#
# ## Trabalho em Grupo
# - **Curso:** FGV MBA - Business Analytics e Big Data
# - **Disciplina:** Análise Econômica e Geração de Valor
# - **Professor:** Bernardo Aflalo
# - **Projeto final:** Detecção de rostos com uso de máscara de proteção
#
# ## Integrantes
# |Github|Kaggle|Nome|Matricula|E-mail|
# |---|---|---|---|---|
# |<a href="https://github.com/DanielFCampos"><img src="https://avatars2.githubusercontent.com/u/31582602?s=460&v=4" title="DanielFCampos" width="40" height="40"></a>|<a href="https://www.kaggle.com/danielferrazcampos"><img src="https://storage.googleapis.com/kaggle-avatars/images/3508055-kg.png" title="DanielFCampos" width="40" height="40"></a>|Daniel Campos|A57635769|[daniel.ferraz.campos@gmail.com](daniel.ferraz.campos@gmail.com)|
# |<a href="https://github.com/ldaniel"><img src="https://avatars2.githubusercontent.com/u/205534?s=460&v=4" title="ldaniel" width="40" height="40"></a>|<a href="https://www.kaggle.com/leandrodaniel"><img src="https://storage.googleapis.com/kaggle-avatars/images/3415144-gr.jpg" title="ldaniel" width="40" height="40"></a>|Leandro Daniel|A57622988|[contato@leandrodaniel.com](contato@leandrodaniel.com)|
# |<a href="https://github.com/ricardobreis"><img src="https://avatars2.githubusercontent.com/u/4885152?s=460&u=470b0bcc829715fd3944d921fec99ad0ea2d6263&v=4" title="ricardobreis" width="40" height="40"></a>|<a href="https://www.kaggle.com/ricardobreis"><img src="https://storage.googleapis.com/kaggle-avatars/images/3201976-kg.jpg" title="ricardobreis" width="40" height="40"></a>|Ricardo Reis|A57590919|[ricardo.l.b.reis@gmail.com](ricardo.l.b.reis@gmail.com)|
# |<a href="https://github.com/RodriGonca"><img src="https://avatars2.githubusercontent.com/u/50252438?s=460&v=4" title="RodriGonca" width="40" height="40"></a>|<a href="https://www.kaggle.com/rodrigonca"><img src="https://storage.googleapis.com/kaggle-avatars/images/3511253-kg.png" title="RodriGonca" width="40" height="40"></a>|Rodrigo Gonçalves|A57566093|[rodrigo.goncalves@me.com](rodrigo.goncalves@me.com)|
# |<a href="https://github.com/ygorlima1"><img src="https://avatars2.githubusercontent.com/u/52429828?s=460&v=4" title="ygorlima1" width="40" height="40"></a>|<a href="https://www.kaggle.com/ygorlima1"><img src="https://storage.googleapis.com/kaggle-avatars/images/3427786-kg.jpg" title="ygorlima1" width="40" height="40"></a>|Ygor Lima|A57549661|[ygor_redesocial@hotmail.com](ygor_redesocial@hotmail.com)|
#
# ## Enunciado
#
# O trabalho poderá ser feito em até 5 pessoas.
#
# O objetivo do trabalho deve contemplar assuntos da aula (deep neural network, convolutional neural network, recurrent neural network) e deve ser escolhido por cada grupo. Na nossa última aula, dia 15/06, os alunos devem apresentar o grupo e qual o tema e o objetivo específico do trabalho. Ex.: 'O grupo, composto pelos alunos (...), terá como trabalho a estimativa dos casos de covid no Brasil utilizando arquiteturas de redes recorrentes, como LSTM e GRU.' Os grupos que tiverem dificuldade de escolher projetos, podem entrar em contato comigo. Algumas sugestões/ inspirações podem ser obtidas em sites de competição (ex Kaggle), mas a solução final deve conter elementos originais.
#
# A entrega final deve ser feita individualmente por cada aluno até o dia 31/07 e deverá conter:
#
# * Os notebooks/ scripts com o trabalho feito e as soluções produzidas pelo grupo (comum a todos os membros do grupo);
#
# * Documentação individual, explicando o que foi feito no trabalho, problemas encontrados e possibilidades de melhoria da solução, em formato de 'mini papers' (2-5 páginas). Cada um deve ter a sua submissão de mini-paper.

# %% [markdown]
# # Desenvolvimento
#
# ## Contexto do trabalho
#
# Vivemos tempos singulares, onde nossa sociedade enfrenta o desafio de combate e prevenção contra o crescente alastramento da COVID-19 em uma escala global. Deste desafiador contexto, emergem efeitos colaterais inéditos na era moderna, como o distanciamento social, dentre diversas mudanças de hábitos.
#
# Com base nas evidências atuais, o vírus COVID-19 é transmitido entre pessoas através de contato próximo e gotículas. Calcula-se que uma pessoa com infecção o transmita para de duas a quatro pessoas.
#
# A Organização Mundial de Saúde (OMS) recomenda o uso de máscaras combinadas com a correta higiene frequente das mãos como parte da chamada EPI (Equipamento de Proteção Individual, do inglês PPE, ou Personal Protective Equipment), dentre outras orientações e recomendações. A Organização Mundial de Saúde disponibiliza uma série de orientações e guias para o uso correto das máscaras, bem com seu descarte e combinação com procedimentos de lavagem das mãos, como uma das medidas possíveis de contenção do alastramento da
# COVID-19.
#
# Recentemente o estado de São Paulo decretou o uso de máscaras de proteção facial como obrigatório, por tempo indeterminado. A medida, que entrou em vigor em 07/05/2020, estabelece o seguinte:
#
# **Uso de máscaras em:**
# * espaços públicos;
# * estabelecimentos que executem atividades essenciais;
# * repartições públicas estaduais;
# * transporte por aplicativo.
#
# **Usados por:**
# * consumidores;
# * fornecedores;
# * clientes;
# * empregados;
# * colaboradores;
# * agentes públicos;
# * prestadores de serviço.
#
#
# ## Objetivos do trabalho
#
# O presente trabalho tem como objetivo principal, desenvolver um modelo de detecção de indivíduos utilizando máscaras faciais, através de técnicas de Deep Learning, como ferramenta possível de ser implementada em sistemas de monitoramento preventivo ao alastramento da COVID-19 em locais e áreas de convívio público ou privado.
#
# ## Pergunta do problema
#
# É possível desenvolver, com técnicas de deep learning, um modelo de detecção de pessoas utilizando máscaras faciais para posterior implementação em sistemas de controle de entrada em espaços públicos, estabelecimentos que executem atividades essenciais, repartições públicas estaduais, transporte por aplicativo para um público alvo de consumidores,  fornecedores,  clientes, empregados, colaboradores, agentes públicos e  prestadores de serviço?

# %% [markdown]
# ## Libraries Utilizadas para Desenvolvimento da Análise

# %%
import os
import numpy as np
import pandas as pd
import random


import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Dense, Dropout, Conv2D, MaxPooling2D, Flatten, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import load_img, img_to_array

import cv2 as cv
import matplotlib.pyplot as plt
import matplotlib.cm as cm

from sklearn.model_selection import train_test_split
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import confusion_matrix, roc_curve, auc, classification_report

from IPython.display import Markdown as md
from PIL import Image

# %%
seed = 42

random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## Data Preparation

# %%
image_size = 256
labels = ['without_mask', 'with_mask']

def get_data(data_dir):
        
    images = []
    
# cria uma lista com o index de cada label com base no nome da raíz do diretório informado.
    for label in labels:
        dir = os.path.join(data_dir, label)
        class_num = labels.index(label)
        
# percorre todas as imagens presentes no diretório, converte para grey_sacale e faz o resizing das imagens.
        for image in os.listdir(dir):    
            image_read = cv.imread(os.path.join(dir,image), cv.IMREAD_GRAYSCALE)
            image_resized = cv.resize(image_read, (image_size, image_size))
            images.append([image_resized, class_num])

    return np.array(images)

load_full_dataset = get_data('/kaggle/input/data/raw/artificially_created_covid_mask_images/')

# %%
mask_count = np.count_nonzero(load_full_dataset[:,1] == 1)
no_mask_count = np.count_nonzero(load_full_dataset[:,1] == 0)

print('Dataset original\n\n', len(load_full_dataset),
      'imagens no dataset com o tamanho', load_full_dataset[1,0].shape,
      '\n\nProporção',
      '\nSem máscara:\t', no_mask_count,
      '\nCom máscara:\t', mask_count)
# Out:
# Dataset original
#
#  1376 imagens no dataset com o tamanho (256, 256)
#
# Proporção
# Sem máscara:	 686
# Com máscara:	 690

# %%
plt.rcParams.update({'font.size': 16})

fig = plt.figure(figsize = (12, 12))
columns = 4
rows = 3

randomlist = []

for i in range(0, int((columns * rows)/2)):
    n = np.random.randint(0, np.count_nonzero(load_full_dataset[:,1] == 0))
    randomlist.append(n)
    
for i in range(0, int((columns * rows)/2)):
    n = np.random.randint(np.count_nonzero(load_full_dataset[:,1] == 0), len(load_full_dataset))
    randomlist.append(n)
    
for i in range(1, columns * rows + 1):
    rnd = np.random.randint(0, len(load_full_dataset))
    img = load_full_dataset[randomlist[i-1]][0]  
    fig.add_subplot(rows, columns, i)
    plt.title(labels[load_full_dataset[randomlist[i-1]][1]])
    plt.axis('off')
    plt.imshow(img, cmap='gray')

plt.show()

# %%
x_features = []
y_labels = []

for feature, label in load_full_dataset:
    x_features.append(feature)
    y_labels.append(label)
    
del load_full_dataset

# %%
x_features = np.array(x_features).reshape(-1, image_size, image_size, 1)
y_labels = np.array(y_labels)
y_labels = np.expand_dims(y_labels, axis =1)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_features, 
                                                    y_labels,
                                                    stratify = y_labels,
                                                    test_size = 0.2, 
                                                    random_state = 2)

del x_features, y_labels

# %%
print('\nTensor de features de treinamento:\t', x_train.shape, 
      '\nImagens:\t', len(x_train), 
      '\nSem máscara:\t', np.count_nonzero(y_train == 0), 
      '\nCom máscara:\t', np.count_nonzero(y_train == 1))

print('\nTensor de labels de treinamento:\t', y_train.shape, 
      '\nQuantidade:\t', len(y_train),
      '\nSem máscara:\t', np.count_nonzero(y_train == 0), 
      '\nCom máscara:\t', np.count_nonzero(y_train == 1))

print('\nTensor de features de teste:\t\t', x_test.shape, 
      '\nImagens:\t', len(x_test),
      '\nSem máscara:\t', np.count_nonzero(y_test == 0), 
      '\nCom máscara:\t', np.count_nonzero(y_test == 1))

print('\nTensor de labels de teste:\t\t', y_test.shape, 
      '\nQuantidade:\t', len(y_test),
      '\nSem máscara:\t', np.count_nonzero(y_test == 0), 
      '\nCom máscara:\t', np.count_nonzero(y_test == 1))
# Out:
# Tensor de features de treinamento:	 (1100, 256, 256, 1)
# Imagens:	 1100
# Sem máscara:	 548
# Com máscara:	 552
#
# Tensor de labels de treinamento:	 (1100, 1)
# Quantidade:	 1100
# Sem máscara:	 548
# Com máscara:	 552
#
# Tensor de features de teste:		 (276, 256, 256, 1)
# Imagens:	 276
# Sem máscara:	 138
# Com máscara:	 138
#
# Tensor de labels de teste:		 (276, 1)
# Quantidade:	 276
# Sem máscara:	 138
# Com máscara:	 138

# %%
x_train = x_train / 255
x_test  = x_test  / 255

# %% [markdown]
# ## Definição da Arquitetura das Redes e Compilação dos Modelos

# %%
i = Input(x_train.shape[1:], name="entrada")
a = Flatten(name="achatamento")(i)
a = Dense(512, activation = 'relu', name="densa1")(a)
a = Dropout(0.4, name="reducao1")(a)
a = Dense(512, activation = 'relu', name="densa2")(a)
a = Dropout(0.3, name="reducao2")(a)
a = Dense(512, activation = 'relu', name="densa3")(a)
a = Dropout(0.1, name="reducao3")(a)
a = Dense(1, activation = 'sigmoid', name="previsao")(a)

model_NN = Model(i,a, name='NN')

model_NN.compile(optimizer = tf.keras.optimizers.SGD(),
                 loss = tf.keras.losses.BinaryCrossentropy(),
                 metrics = [tf.keras.metrics.Accuracy()])

# %%
i = Input(x_train.shape[1:], name="entrada")
b = Conv2D(32, (3,3), activation ='relu', padding = 'same', name="convolucao2d1")(i)
b = BatchNormalization(name="normalizacao1")(b)
b = Conv2D(32, (3,3), activation ='relu', padding = 'same', name="convolucao2d2")(b)
b = BatchNormalization(name="normalizacao2")(b)
b = MaxPooling2D(2,2, name="acumulacao1")(b)
b = Conv2D(64, (3,3), activation ='relu', padding = 'same', name="convolucao2d3")(b)
b = BatchNormalization(name="normalizacao3")(b)
b = Conv2D(64, (3,3), activation ='relu', padding = 'same', name="convolucao2d4")(b)
b = BatchNormalization(name="normalizacao4")(b)
b = MaxPooling2D(2,2, name="acumulacao2")(b)
b = Conv2D(128, (3,3), activation ='relu', padding = 'same', name="convolucao2d5")(b)
b = BatchNormalization(name="normalizacao5")(b)
b = Conv2D(128, (3,3), activation ='relu', padding = 'same', name="convolucao2d6")(b)
b = BatchNormalization(name="normalizacao6")(b)
b = MaxPooling2D(2,2, name="acumulacao3")(b)
b = Conv2D(256, (3,3), activation ='relu', padding = 'same', name="convolucao2d7")(b)
b = BatchNormalization(name="normalizacao7")(b)
b = Conv2D(256, (3,3), activation ='relu', padding = 'same', name="convolucao2d8")(b)
b = BatchNormalization(name="normalizacao8")(b)
b = MaxPooling2D(2,2, name="acumulacao4")(b)
b = Flatten(name="achatamento")(b)
b = Dense(512, activation = 'relu', name="densa1")(b)
b = Dropout(0.4, name="reducao1")(b)
b = Dense(512, activation = 'relu', name="densa2")(b)
b = Dropout(0.3, name="reducao2")(b)
b = Dense(512, activation = 'relu', name="densa3")(b)
b = Dropout(0.1, name="reducao3")(b)
b = Dense(1, activation = 'sigmoid', name="previsao")(b)

model_CNN = Model(i, b, name='CNN')

model_CNN.compile(optimizer = tf.keras.optimizers.SGD(),
                  loss = tf.keras.losses.BinaryCrossentropy(),
                  metrics = [tf.keras.metrics.Accuracy()])

# %% [markdown]
# ## Visualizando a Arquitetura dos Modelos
# ### Rede Neural Simples

# %%
model_NN.summary()
# Out:
# Model: "NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# entrada (InputLayer)         [(None, 256, 256, 1)]     0
# _________________________________________________________________
# achatamento (Flatten)        (None, 65536)             0
# _________________________________________________________________
# densa1 (Dense)               (None, 512)               33554944
# _________________________________________________________________
# reducao1 (Dropout)           (None, 512)               0
# _________________________________________________________________
# densa2 (Dense)               (None, 512)               262656
# _________________________________________________________________
# reducao2 (Dropout)           (None, 512)               0
# _________________________________________________________________
# densa3 (Dense)               (None, 512)               262656
# _________________________________________________________________
# reducao3 (Dropout)           (None, 512)               0
# _________________________________________________________________
# previsao (Dense)             (None, 1)                 513
# =================================================================
# Total params: 34,080,769
# Trainable params: 34,080,769
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Rede Neural com Convoluções

# %%
model_CNN.summary()
# Out:
# Model: "CNN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# entrada (InputLayer)         [(None, 256, 256, 1)]     0
# _________________________________________________________________
# convolucao2d1 (Conv2D)       (None, 256, 256, 32)      320
# _________________________________________________________________
# normalizacao1 (BatchNormaliz (None, 256, 256, 32)      128
# _________________________________________________________________
# convolucao2d2 (Conv2D)       (None, 256, 256, 32)      9248
# _________________________________________________________________
# normalizacao2 (BatchNormaliz (None, 256, 256, 32)      128
# _________________________________________________________________
# acumulacao1 (MaxPooling2D)   (None, 128, 128, 32)      0
# _________________________________________________________________
# convolucao2d3 (Conv2D)       (None, 128, 128, 64)      18496
# _________________________________________________________________
# normalizacao3 (BatchNormaliz (None, 128, 128, 64)      256
# _________________________________________________________________
# convolucao2d4 (Conv2D)       (None, 128, 128, 64)      36928
# _________________________________________________________________
# normalizacao4 (BatchNormaliz (None, 128, 128, 64)      256
# _________________________________________________________________
# acumulacao2 (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# convolucao2d5 (Conv2D)       (None, 64, 64, 128)       73856
# _________________________________________________________________
# normalizacao5 (BatchNormaliz (None, 64, 64, 128)       512
# _________________________________________________________________
# convolucao2d6 (Conv2D)       (None, 64, 64, 128)       147584
# _________________________________________________________________
# normalizacao6 (BatchNormaliz (None, 64, 64, 128)       512
# _________________________________________________________________
# acumulacao3 (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# convolucao2d7 (Conv2D)       (None, 32, 32, 256)       295168
# _________________________________________________________________
# normalizacao7 (BatchNormaliz (None, 32, 32, 256)       1024
# _________________________________________________________________
# convolucao2d8 (Conv2D)       (None, 32, 32, 256)       590080
# _________________________________________________________________
# normalizacao8 (BatchNormaliz (None, 32, 32, 256)       1024
# _________________________________________________________________
# acumulacao4 (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# achatamento (Flatten)        (None, 65536)             0
# _________________________________________________________________
# densa1 (Dense)               (None, 512)               33554944
# _________________________________________________________________
# reducao1 (Dropout)           (None, 512)               0
# _________________________________________________________________
# densa2 (Dense)               (None, 512)               262656
# _________________________________________________________________
# reducao2 (Dropout)           (None, 512)               0
# _________________________________________________________________
# densa3 (Dense)               (None, 512)               262656
# _________________________________________________________________
# reducao3 (Dropout)           (None, 512)               0
# _________________________________________________________________
# previsao (Dense)             (None, 1)                 513
# =================================================================
# Total params: 35,256,289
# Trainable params: 35,254,369
# Non-trainable params: 1,920
# _________________________________________________________________

# %% [markdown]
# ## Data Augmentation

# %%
batch_size = 32

train_gen = ImageDataGenerator(rotation_range = 10,
                               horizontal_flip = True,
                               width_shift_range = 0.1,
                               height_shift_range = 0.1,
                               rescale = 1.,
                               zoom_range = 0.2,
                               fill_mode = 'nearest',
                               cval = 0)

train_generator_NN = train_gen.flow(x_train, y_train, batch_size)
train_generator_CNN = train_gen.flow(x_train, y_train, batch_size)

steps_per_epoch = x_train.shape[0] // batch_size

checkpoint_NN = ModelCheckpoint('model_NN.h5', 
                                monitor = 'val_loss', 
                                verbose = 0, 
                                save_best_only = True, 
                                mode = 'auto')

checkpoint_CNN = ModelCheckpoint('model_CNN.h5', 
                                 monitor = 'val_loss', 
                                 verbose = 0, 
                                 save_best_only = True, 
                                 mode = 'auto')

# %% [markdown]
# ## Treinamento dos Modelos

# %%
epochs = 150 # Reduce number of epochs for testing purposes

history_NN = model_NN.fit(train_generator_NN, 
                          validation_data = (x_test, y_test), 
                          steps_per_epoch = steps_per_epoch, 
                          epochs = epochs,
                          callbacks = [checkpoint_NN],
                          verbose = 2)

history_CNN = model_CNN.fit(train_generator_CNN, 
                            validation_data = (x_test, y_test), 
                            steps_per_epoch = steps_per_epoch, 
                            epochs = epochs,
                            callbacks = [checkpoint_CNN],
                            verbose = 2)
# Out:
# Train for 34 steps, validate on 276 samples
# Epoch 1/150
# 34/34 - 6s - loss: 0.8025 - accuracy: 0.0000e+00 - val_loss: 0.6972 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 34/34 - 5s - loss: 0.7117 - accuracy: 0.0000e+00 - val_loss: 0.6211 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 34/34 - 5s - loss: 0.6441 - accuracy: 0.0000e+00 - val_loss: 0.6746 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 34/34 - 5s - loss: 0.6485 - accuracy: 0.0000e+00 - val_loss: 0.6197 - val_accuracy: 0.0000e+00
# Epoch 5/150
# 34/34 - 5s - loss: 0.6281 - accuracy: 0.0000e+00 - val_loss: 0.5597 - val_accuracy: 0.0000e+00
# Epoch 6/150
# 34/34 - 5s - loss: 0.6053 - accuracy: 0.0000e+00 - val_loss: 0.6373 - val_accuracy: 0.0000e+00
# Epoch 7/150
# 34/34 - 5s - loss: 0.6192 - accuracy: 0.0000e+00 - val_loss: 0.5624 - val_accuracy: 0.0000e+00
# Epoch 8/150
# 34/34 - 5s - loss: 0.5902 - accuracy: 0.0000e+00 - val_loss: 0.5188 - val_accuracy: 0.0000e+00
# Epoch 9/150
# 34/34 - 5s - loss: 0.5872 - accuracy: 0.0000e+00 - val_loss: 0.5245 - val_accuracy: 0.0000e+00
# Epoch 10/150
# 34/34 - 4s - loss: 0.5884 - accuracy: 0.0000e+00 - val_loss: 0.5190 - val_accuracy: 0.0000e+00
# Epoch 11/150
# 34/34 - 5s - loss: 0.5689 - accuracy: 0.0000e+00 - val_loss: 0.5185 - val_accuracy: 0.0000e+00
# Epoch 12/150
# 34/34 - 5s - loss: 0.5740 - accuracy: 0.0000e+00 - val_loss: 0.4861 - val_accuracy: 0.0000e+00
# Epoch 13/150
# 34/34 - 5s - loss: 0.5378 - accuracy: 0.0000e+00 - val_loss: 0.4667 - val_accuracy: 0.0000e+00
# Epoch 14/150
# 34/34 - 5s - loss: 0.5590 - accuracy: 0.0000e+00 - val_loss: 0.4678 - val_accuracy: 0.0000e+00
# Epoch 15/150
# 34/34 - 4s - loss: 0.5425 - accuracy: 0.0000e+00 - val_loss: 0.4892 - val_accuracy: 0.0000e+00
# Epoch 16/150
# 34/34 - 5s - loss: 0.5758 - accuracy: 0.0000e+00 - val_loss: 0.4472 - val_accuracy: 0.0000e+00
# Epoch 17/150
# 34/34 - 4s - loss: 0.5189 - accuracy: 0.0000e+00 - val_loss: 0.4665 - val_accuracy: 0.0000e+00
# Epoch 18/150
# 34/34 - 5s - loss: 0.5409 - accuracy: 0.0000e+00 - val_loss: 0.4550 - val_accuracy: 0.0000e+00
# Epoch 19/150
# 34/34 - 5s - loss: 0.5511 - accuracy: 0.0000e+00 - val_loss: 0.4387 - val_accuracy: 0.0000e+00
# Epoch 20/150
# 34/34 - 5s - loss: 0.5200 - accuracy: 0.0000e+00 - val_loss: 0.4385 - val_accuracy: 0.0000e+00
# Epoch 21/150
# 34/34 - 5s - loss: 0.5268 - accuracy: 0.0000e+00 - val_loss: 0.4523 - val_accuracy: 0.0000e+00
# Epoch 22/150
# 34/34 - 5s - loss: 0.5241 - accuracy: 0.0000e+00 - val_loss: 0.4366 - val_accuracy: 0.0000e+00
# Epoch 23/150
# 34/34 - 5s - loss: 0.5446 - accuracy: 0.0000e+00 - val_loss: 0.4378 - val_accuracy: 0.0000e+00
# Epoch 24/150
# 34/34 - 5s - loss: 0.5286 - accuracy: 0.0000e+00 - val_loss: 0.4245 - val_accuracy: 0.0000e+00
# Epoch 25/150
# 34/34 - 5s - loss: 0.5410 - accuracy: 0.0000e+00 - val_loss: 0.4143 - val_accuracy: 0.0000e+00
# Epoch 26/150
# 34/34 - 5s - loss: 0.5181 - accuracy: 0.0000e+00 - val_loss: 0.4091 - val_accuracy: 0.0000e+00
# Epoch 27/150
# 34/34 - 5s - loss: 0.4903 - accuracy: 0.0000e+00 - val_loss: 0.4073 - val_accuracy: 0.0000e+00
# Epoch 28/150
# 34/34 - 5s - loss: 0.5038 - accuracy: 0.0000e+00 - val_loss: 0.4011 - val_accuracy: 0.0000e+00
# Epoch 29/150
# 34/34 - 4s - loss: 0.4875 - accuracy: 0.0000e+00 - val_loss: 0.4117 - val_accuracy: 0.0000e+00
# Epoch 30/150
# 34/34 - 5s - loss: 0.5035 - accuracy: 0.0000e+00 - val_loss: 0.4629 - val_accuracy: 0.0000e+00
# Epoch 31/150
# 34/34 - 5s - loss: 0.4848 - accuracy: 0.0000e+00 - val_loss: 0.3825 - val_accuracy: 0.0000e+00
# Epoch 32/150
# 34/34 - 5s - loss: 0.4891 - accuracy: 0.0000e+00 - val_loss: 0.3984 - val_accuracy: 0.0000e+00
# Epoch 33/150
# 34/34 - 5s - loss: 0.4968 - accuracy: 0.0000e+00 - val_loss: 0.4509 - val_accuracy: 0.0000e+00
# Epoch 34/150
# 34/34 - 4s - loss: 0.4877 - accuracy: 0.0000e+00 - val_loss: 0.4031 - val_accuracy: 0.0000e+00
# Epoch 35/150
# 34/34 - 5s - loss: 0.4681 - accuracy: 0.0000e+00 - val_loss: 0.3890 - val_accuracy: 0.0000e+00
# Epoch 36/150
# 34/34 - 4s - loss: 0.5083 - accuracy: 0.0000e+00 - val_loss: 0.3904 - val_accuracy: 0.0000e+00
# Epoch 37/150
# 34/34 - 5s - loss: 0.4723 - accuracy: 0.0000e+00 - val_loss: 0.3987 - val_accuracy: 0.0000e+00
# Epoch 38/150
# 34/34 - 4s - loss: 0.4716 - accuracy: 0.0000e+00 - val_loss: 0.3839 - val_accuracy: 0.0000e+00
# Epoch 39/150
# 34/34 - 5s - loss: 0.5035 - accuracy: 0.0000e+00 - val_loss: 0.4116 - val_accuracy: 0.0000e+00
# Epoch 40/150
# 34/34 - 5s - loss: 0.4653 - accuracy: 0.0000e+00 - val_loss: 0.3554 - val_accuracy: 0.0000e+00
# Epoch 41/150
# 34/34 - 4s - loss: 0.4732 - accuracy: 0.0000e+00 - val_loss: 0.4012 - val_accuracy: 0.0000e+00
# Epoch 42/150
# 34/34 - 5s - loss: 0.4491 - accuracy: 0.0000e+00 - val_loss: 0.3790 - val_accuracy: 0.0000e+00
# Epoch 43/150
# 34/34 - 5s - loss: 0.4450 - accuracy: 0.0000e+00 - val_loss: 0.3532 - val_accuracy: 0.0000e+00
# Epoch 44/150
# 34/34 - 5s - loss: 0.4385 - accuracy: 0.0000e+00 - val_loss: 0.3524 - val_accuracy: 0.0000e+00
# Epoch 45/150
# 34/34 - 5s - loss: 0.4447 - accuracy: 0.0000e+00 - val_loss: 0.3407 - val_accuracy: 0.0000e+00
# Epoch 46/150
# 34/34 - 5s - loss: 0.4625 - accuracy: 0.0000e+00 - val_loss: 0.3749 - val_accuracy: 0.0000e+00
# Epoch 47/150
# 34/34 - 5s - loss: 0.4305 - accuracy: 0.0000e+00 - val_loss: 0.3513 - val_accuracy: 0.0000e+00
# Epoch 48/150
# 34/34 - 5s - loss: 0.4157 - accuracy: 0.0000e+00 - val_loss: 0.3231 - val_accuracy: 0.0000e+00
# Epoch 49/150
# 34/34 - 4s - loss: 0.4355 - accuracy: 0.0000e+00 - val_loss: 0.3408 - val_accuracy: 0.0000e+00
# Epoch 50/150
# 34/34 - 4s - loss: 0.4387 - accuracy: 0.0000e+00 - val_loss: 0.3532 - val_accuracy: 0.0000e+00
# Epoch 51/150
# 34/34 - 5s - loss: 0.4384 - accuracy: 0.0000e+00 - val_loss: 0.3821 - val_accuracy: 0.0000e+00
# Epoch 52/150
# 34/34 - 4s - loss: 0.4326 - accuracy: 0.0000e+00 - val_loss: 0.3669 - val_accuracy: 0.0000e+00
# Epoch 53/150
# 34/34 - 5s - loss: 0.4379 - accuracy: 0.0000e+00 - val_loss: 0.3707 - val_accuracy: 0.0000e+00
# Epoch 54/150
# 34/34 - 4s - loss: 0.4325 - accuracy: 0.0000e+00 - val_loss: 0.3371 - val_accuracy: 0.0000e+00
# Epoch 55/150
# 34/34 - 5s - loss: 0.4347 - accuracy: 0.0000e+00 - val_loss: 0.4155 - val_accuracy: 0.0000e+00
# Epoch 56/150
# 34/34 - 5s - loss: 0.4217 - accuracy: 0.0000e+00 - val_loss: 0.3459 - val_accuracy: 0.0000e+00
# Epoch 57/150
# 34/34 - 5s - loss: 0.4090 - accuracy: 0.0000e+00 - val_loss: 0.3237 - val_accuracy: 0.0000e+00
# Epoch 58/150
# 34/34 - 5s - loss: 0.4121 - accuracy: 0.0000e+00 - val_loss: 0.3837 - val_accuracy: 0.0000e+00
# Epoch 59/150
# 34/34 - 4s - loss: 0.4070 - accuracy: 0.0000e+00 - val_loss: 0.3663 - val_accuracy: 0.0000e+00
# Epoch 60/150
# 34/34 - 5s - loss: 0.4463 - accuracy: 0.0000e+00 - val_loss: 0.3252 - val_accuracy: 0.0000e+00
# Epoch 61/150
# 34/34 - 5s - loss: 0.3994 - accuracy: 0.0000e+00 - val_loss: 0.3173 - val_accuracy: 0.0000e+00
# Epoch 62/150
# 34/34 - 5s - loss: 0.4154 - accuracy: 0.0000e+00 - val_loss: 0.3280 - val_accuracy: 0.0000e+00
# Epoch 63/150
# 34/34 - 5s - loss: 0.4292 - accuracy: 0.0000e+00 - val_loss: 0.3454 - val_accuracy: 0.0000e+00
# Epoch 64/150
# 34/34 - 5s - loss: 0.4138 - accuracy: 0.0000e+00 - val_loss: 0.3271 - val_accuracy: 0.0000e+00
# Epoch 65/150
# 34/34 - 5s - loss: 0.4335 - accuracy: 0.0000e+00 - val_loss: 0.3221 - val_accuracy: 0.0000e+00
# Epoch 66/150
# 34/34 - 4s - loss: 0.4135 - accuracy: 0.0000e+00 - val_loss: 0.3598 - val_accuracy: 0.0000e+00
# Epoch 67/150
# 34/34 - 5s - loss: 0.3979 - accuracy: 0.0000e+00 - val_loss: 0.3106 - val_accuracy: 0.0000e+00
# Epoch 68/150
# 34/34 - 5s - loss: 0.3987 - accuracy: 0.0000e+00 - val_loss: 0.3108 - val_accuracy: 0.0000e+00
# Epoch 69/150
# 34/34 - 5s - loss: 0.4086 - accuracy: 0.0000e+00 - val_loss: 0.3107 - val_accuracy: 0.0000e+00
# Epoch 70/150
# 34/34 - 5s - loss: 0.4036 - accuracy: 0.0000e+00 - val_loss: 0.3062 - val_accuracy: 0.0000e+00
# Epoch 71/150
# 34/34 - 4s - loss: 0.4075 - accuracy: 0.0000e+00 - val_loss: 0.3121 - val_accuracy: 0.0000e+00
# Epoch 72/150
# 34/34 - 5s - loss: 0.4083 - accuracy: 0.0000e+00 - val_loss: 0.3189 - val_accuracy: 0.0000e+00
# Epoch 73/150
# 34/34 - 5s - loss: 0.4020 - accuracy: 0.0000e+00 - val_loss: 0.3019 - val_accuracy: 0.0000e+00
# Epoch 74/150
# 34/34 - 5s - loss: 0.4076 - accuracy: 0.0000e+00 - val_loss: 0.3090 - val_accuracy: 0.0000e+00
# Epoch 75/150
# 34/34 - 4s - loss: 0.4050 - accuracy: 0.0000e+00 - val_loss: 0.3294 - val_accuracy: 0.0000e+00
# Epoch 76/150
# 34/34 - 5s - loss: 0.3726 - accuracy: 0.0000e+00 - val_loss: 0.3005 - val_accuracy: 0.0000e+00
# Epoch 77/150
# 34/34 - 5s - loss: 0.3919 - accuracy: 0.0000e+00 - val_loss: 0.2946 - val_accuracy: 0.0000e+00
# Epoch 78/150
# 34/34 - 4s - loss: 0.3701 - accuracy: 0.0000e+00 - val_loss: 0.4309 - val_accuracy: 0.0000e+00
# Epoch 79/150
# 34/34 - 5s - loss: 0.4161 - accuracy: 0.0000e+00 - val_loss: 0.3322 - val_accuracy: 0.0000e+00
# Epoch 80/150
# 34/34 - 5s - loss: 0.3949 - accuracy: 0.0000e+00 - val_loss: 0.3036 - val_accuracy: 0.0000e+00
# Epoch 81/150
# 34/34 - 5s - loss: 0.4098 - accuracy: 0.0000e+00 - val_loss: 0.3511 - val_accuracy: 0.0000e+00
# Epoch 82/150
# 34/34 - 5s - loss: 0.3922 - accuracy: 0.0000e+00 - val_loss: 0.3282 - val_accuracy: 0.0000e+00
# Epoch 83/150
# 34/34 - 5s - loss: 0.3787 - accuracy: 0.0000e+00 - val_loss: 0.3230 - val_accuracy: 0.0000e+00
# Epoch 84/150
# 34/34 - 4s - loss: 0.3850 - accuracy: 0.0000e+00 - val_loss: 0.3117 - val_accuracy: 0.0000e+00
# Epoch 85/150
# 34/34 - 4s - loss: 0.3925 - accuracy: 0.0000e+00 - val_loss: 0.3147 - val_accuracy: 0.0000e+00
# Epoch 86/150
# 34/34 - 5s - loss: 0.3681 - accuracy: 0.0000e+00 - val_loss: 0.3103 - val_accuracy: 0.0000e+00
# Epoch 87/150
# 34/34 - 4s - loss: 0.3722 - accuracy: 0.0000e+00 - val_loss: 0.3221 - val_accuracy: 0.0000e+00
# Epoch 88/150
# 34/34 - 5s - loss: 0.3619 - accuracy: 0.0000e+00 - val_loss: 0.2805 - val_accuracy: 0.0000e+00
# Epoch 89/150
# 34/34 - 4s - loss: 0.3528 - accuracy: 0.0000e+00 - val_loss: 0.2898 - val_accuracy: 0.0000e+00
# Epoch 90/150
# 34/34 - 5s - loss: 0.3793 - accuracy: 0.0000e+00 - val_loss: 0.3098 - val_accuracy: 0.0000e+00
# Epoch 91/150
# 34/34 - 4s - loss: 0.3654 - accuracy: 0.0000e+00 - val_loss: 0.2923 - val_accuracy: 0.0000e+00
# Epoch 92/150
# 34/34 - 4s - loss: 0.3705 - accuracy: 0.0000e+00 - val_loss: 0.2874 - val_accuracy: 0.0000e+00
# Epoch 93/150
# 34/34 - 5s - loss: 0.3717 - accuracy: 0.0000e+00 - val_loss: 0.3006 - val_accuracy: 0.0000e+00
# Epoch 94/150
# 34/34 - 5s - loss: 0.3441 - accuracy: 0.0000e+00 - val_loss: 0.3224 - val_accuracy: 0.0000e+00
# Epoch 95/150
# 34/34 - 5s - loss: 0.3587 - accuracy: 0.0000e+00 - val_loss: 0.3140 - val_accuracy: 0.0000e+00
# Epoch 96/150
# 34/34 - 4s - loss: 0.3778 - accuracy: 0.0000e+00 - val_loss: 0.3279 - val_accuracy: 0.0000e+00
# Epoch 97/150
# 34/34 - 5s - loss: 0.3917 - accuracy: 0.0000e+00 - val_loss: 0.3414 - val_accuracy: 0.0000e+00
# Epoch 98/150
# 34/34 - 4s - loss: 0.3785 - accuracy: 0.0000e+00 - val_loss: 0.3180 - val_accuracy: 0.0000e+00
# Epoch 99/150
# 34/34 - 4s - loss: 0.3823 - accuracy: 0.0000e+00 - val_loss: 0.3181 - val_accuracy: 0.0000e+00
# Epoch 100/150
# 34/34 - 5s - loss: 0.3694 - accuracy: 0.0000e+00 - val_loss: 0.3473 - val_accuracy: 0.0000e+00
# Epoch 101/150
# 34/34 - 4s - loss: 0.3663 - accuracy: 0.0000e+00 - val_loss: 0.2865 - val_accuracy: 0.0000e+00
# Epoch 102/150
# 34/34 - 5s - loss: 0.3682 - accuracy: 0.0000e+00 - val_loss: 0.3073 - val_accuracy: 0.0000e+00
# Epoch 103/150
# 34/34 - 4s - loss: 0.3640 - accuracy: 0.0000e+00 - val_loss: 0.3280 - val_accuracy: 0.0000e+00
# Epoch 104/150
# 34/34 - 4s - loss: 0.3566 - accuracy: 0.0000e+00 - val_loss: 0.3568 - val_accuracy: 0.0000e+00
# Epoch 105/150
# 34/34 - 5s - loss: 0.3632 - accuracy: 0.0000e+00 - val_loss: 0.3052 - val_accuracy: 0.0000e+00
# Epoch 106/150
# 34/34 - 5s - loss: 0.3349 - accuracy: 0.0000e+00 - val_loss: 0.4116 - val_accuracy: 0.0000e+00
# Epoch 107/150
# 34/34 - 5s - loss: 0.3706 - accuracy: 0.0000e+00 - val_loss: 0.2791 - val_accuracy: 0.0000e+00
# Epoch 108/150
# 34/34 - 5s - loss: 0.3426 - accuracy: 0.0000e+00 - val_loss: 0.3038 - val_accuracy: 0.0000e+00
# Epoch 109/150
# 34/34 - 5s - loss: 0.3808 - accuracy: 9.3633e-04 - val_loss: 0.2934 - val_accuracy: 0.0000e+00
# Epoch 110/150
# 34/34 - 4s - loss: 0.3422 - accuracy: 0.0000e+00 - val_loss: 0.3210 - val_accuracy: 0.0000e+00
# Epoch 111/150
# 34/34 - 5s - loss: 0.3820 - accuracy: 0.0000e+00 - val_loss: 0.2680 - val_accuracy: 0.0000e+00
# Epoch 112/150
# 34/34 - 4s - loss: 0.3711 - accuracy: 0.0000e+00 - val_loss: 0.3229 - val_accuracy: 0.0000e+00
# Epoch 113/150
# 34/34 - 5s - loss: 0.3534 - accuracy: 0.0000e+00 - val_loss: 0.2998 - val_accuracy: 0.0000e+00
# Epoch 114/150
# 34/34 - 5s - loss: 0.3487 - accuracy: 0.0000e+00 - val_loss: 0.3047 - val_accuracy: 0.0000e+00
# Epoch 115/150
# 34/34 - 5s - loss: 0.3544 - accuracy: 0.0000e+00 - val_loss: 0.3714 - val_accuracy: 0.0000e+00
# Epoch 116/150
# 34/34 - 5s - loss: 0.3504 - accuracy: 0.0000e+00 - val_loss: 0.3205 - val_accuracy: 0.0000e+00
# Epoch 117/150
# 34/34 - 4s - loss: 0.3310 - accuracy: 0.0000e+00 - val_loss: 0.3130 - val_accuracy: 0.0000e+00
# Epoch 118/150
# 34/34 - 5s - loss: 0.3800 - accuracy: 0.0000e+00 - val_loss: 0.3497 - val_accuracy: 0.0000e+00
# Epoch 119/150
# 34/34 - 5s - loss: 0.3197 - accuracy: 0.0000e+00 - val_loss: 0.3574 - val_accuracy: 0.0000e+00
# Epoch 120/150
# 34/34 - 5s - loss: 0.3566 - accuracy: 0.0000e+00 - val_loss: 0.3037 - val_accuracy: 0.0000e+00
# Epoch 121/150
# 34/34 - 5s - loss: 0.3494 - accuracy: 0.0000e+00 - val_loss: 0.3217 - val_accuracy: 0.0000e+00
# Epoch 122/150
# 34/34 - 5s - loss: 0.3510 - accuracy: 0.0000e+00 - val_loss: 0.2900 - val_accuracy: 0.0000e+00
# Epoch 123/150
# 34/34 - 5s - loss: 0.3385 - accuracy: 0.0000e+00 - val_loss: 0.3157 - val_accuracy: 0.0000e+00
# Epoch 124/150
# 34/34 - 5s - loss: 0.3498 - accuracy: 0.0000e+00 - val_loss: 0.3229 - val_accuracy: 0.0000e+00
# Epoch 125/150
# 34/34 - 5s - loss: 0.3441 - accuracy: 0.0000e+00 - val_loss: 0.2988 - val_accuracy: 0.0000e+00
# Epoch 126/150
# 34/34 - 5s - loss: 0.3328 - accuracy: 0.0000e+00 - val_loss: 0.2818 - val_accuracy: 0.0000e+00
# Epoch 127/150
# 34/34 - 5s - loss: 0.3447 - accuracy: 0.0000e+00 - val_loss: 0.3375 - val_accuracy: 0.0000e+00
# Epoch 128/150
# 34/34 - 5s - loss: 0.3408 - accuracy: 0.0000e+00 - val_loss: 0.3112 - val_accuracy: 0.0000e+00
# Epoch 129/150
# 34/34 - 4s - loss: 0.3466 - accuracy: 0.0000e+00 - val_loss: 0.3998 - val_accuracy: 0.0000e+00
# Epoch 130/150
# 34/34 - 5s - loss: 0.3201 - accuracy: 0.0000e+00 - val_loss: 0.3087 - val_accuracy: 0.0000e+00
# Epoch 131/150
# 34/34 - 4s - loss: 0.3449 - accuracy: 0.0000e+00 - val_loss: 0.2919 - val_accuracy: 0.0000e+00
# Epoch 132/150
# 34/34 - 5s - loss: 0.3733 - accuracy: 0.0000e+00 - val_loss: 0.3206 - val_accuracy: 0.0000e+00
# Epoch 133/150
# 34/34 - 5s - loss: 0.3310 - accuracy: 0.0000e+00 - val_loss: 0.3266 - val_accuracy: 0.0000e+00
# Epoch 134/150
# 34/34 - 5s - loss: 0.3365 - accuracy: 0.0000e+00 - val_loss: 0.3078 - val_accuracy: 0.0000e+00
# Epoch 135/150
# 34/34 - 5s - loss: 0.3384 - accuracy: 0.0000e+00 - val_loss: 0.2961 - val_accuracy: 0.0000e+00
# Epoch 136/150
# 34/34 - 4s - loss: 0.3139 - accuracy: 0.0000e+00 - val_loss: 0.3223 - val_accuracy: 0.0000e+00
# Epoch 137/150
# 34/34 - 5s - loss: 0.3558 - accuracy: 0.0000e+00 - val_loss: 0.3120 - val_accuracy: 0.0000e+00
# Epoch 138/150
# 34/34 - 4s - loss: 0.3531 - accuracy: 0.0000e+00 - val_loss: 0.3712 - val_accuracy: 0.0000e+00
# Epoch 139/150
# 34/34 - 5s - loss: 0.3425 - accuracy: 0.0000e+00 - val_loss: 0.3436 - val_accuracy: 0.0000e+00
# Epoch 140/150
# 34/34 - 5s - loss: 0.3095 - accuracy: 0.0000e+00 - val_loss: 0.2843 - val_accuracy: 0.0000e+00
# Epoch 141/150
# 34/34 - 5s - loss: 0.3525 - accuracy: 0.0000e+00 - val_loss: 0.3080 - val_accuracy: 0.0000e+00
# Epoch 142/150
# 34/34 - 5s - loss: 0.3198 - accuracy: 0.0000e+00 - val_loss: 0.3166 - val_accuracy: 0.0000e+00
# Epoch 143/150
# 34/34 - 5s - loss: 0.3250 - accuracy: 0.0000e+00 - val_loss: 0.3301 - val_accuracy: 0.0000e+00
# Epoch 144/150
# 34/34 - 5s - loss: 0.3364 - accuracy: 0.0000e+00 - val_loss: 0.3207 - val_accuracy: 0.0000e+00
# Epoch 145/150
# 34/34 - 5s - loss: 0.3410 - accuracy: 0.0000e+00 - val_loss: 0.3548 - val_accuracy: 0.0000e+00
# Epoch 146/150
# 34/34 - 5s - loss: 0.3049 - accuracy: 0.0000e+00 - val_loss: 0.2901 - val_accuracy: 0.0000e+00
# Epoch 147/150
# 34/34 - 5s - loss: 0.3309 - accuracy: 0.0000e+00 - val_loss: 0.3010 - val_accuracy: 0.0000e+00
# Epoch 148/150
# 34/34 - 5s - loss: 0.3058 - accuracy: 0.0000e+00 - val_loss: 0.3030 - val_accuracy: 0.0000e+00
# Epoch 149/150
# 34/34 - 5s - loss: 0.3453 - accuracy: 0.0000e+00 - val_loss: 0.3307 - val_accuracy: 0.0000e+00
# Epoch 150/150
# 34/34 - 5s - loss: 0.3525 - accuracy: 0.0000e+00 - val_loss: 0.3866 - val_accuracy: 0.0000e+00
# Train for 34 steps, validate on 276 samples
# Epoch 1/150
# 34/34 - 13s - loss: 0.7793 - accuracy: 0.0000e+00 - val_loss: 0.6965 - val_accuracy: 0.0000e+00
# Epoch 2/150
# 34/34 - 7s - loss: 0.2842 - accuracy: 0.0000e+00 - val_loss: 0.7813 - val_accuracy: 0.0000e+00
# Epoch 3/150
# 34/34 - 7s - loss: 0.2026 - accuracy: 0.0000e+00 - val_loss: 0.8398 - val_accuracy: 0.0000e+00
# Epoch 4/150
# 34/34 - 7s - loss: 0.1959 - accuracy: 0.0000e+00 - val_loss: 1.2193 - val_accuracy: 0.0000e+00
# Epoch 5/150
# 34/34 - 7s - loss: 0.1594 - accuracy: 9.3633e-04 - val_loss: 1.4374 - val_accuracy: 0.0000e+00
# Epoch 6/150
# 34/34 - 7s - loss: 0.1271 - accuracy: 0.0056 - val_loss: 1.9465 - val_accuracy: 0.0000e+00
# Epoch 7/150
# 34/34 - 7s - loss: 0.1084 - accuracy: 0.0028 - val_loss: 2.5598 - val_accuracy: 0.0000e+00
# Epoch 8/150
# 34/34 - 7s - loss: 0.0975 - accuracy: 0.0066 - val_loss: 2.9250 - val_accuracy: 0.0000e+00
# Epoch 9/150
# 34/34 - 7s - loss: 0.0819 - accuracy: 0.0047 - val_loss: 2.0709 - val_accuracy: 0.0000e+00
# Epoch 10/150
# 34/34 - 7s - loss: 0.0845 - accuracy: 0.0131 - val_loss: 3.2457 - val_accuracy: 0.0000e+00
# Epoch 11/150
# 34/34 - 7s - loss: 0.0701 - accuracy: 0.0150 - val_loss: 3.9039 - val_accuracy: 0.0000e+00
# Epoch 12/150
# 34/34 - 7s - loss: 0.0592 - accuracy: 0.0328 - val_loss: 3.7188 - val_accuracy: 0.0000e+00
# Epoch 13/150
# 34/34 - 7s - loss: 0.0563 - accuracy: 0.0290 - val_loss: 3.5281 - val_accuracy: 0.0000e+00
# Epoch 14/150
# 34/34 - 7s - loss: 0.0338 - accuracy: 0.0524 - val_loss: 1.4231 - val_accuracy: 0.0000e+00
# Epoch 15/150
# 34/34 - 7s - loss: 0.0323 - accuracy: 0.0702 - val_loss: 0.9279 - val_accuracy: 0.0000e+00
# Epoch 16/150
# 34/34 - 7s - loss: 0.0435 - accuracy: 0.0515 - val_loss: 0.6789 - val_accuracy: 0.0000e+00
# Epoch 17/150
# 34/34 - 7s - loss: 0.0292 - accuracy: 0.0800 - val_loss: 0.1284 - val_accuracy: 0.0000e+00
# Epoch 18/150
# 34/34 - 7s - loss: 0.0365 - accuracy: 0.1077 - val_loss: 0.1220 - val_accuracy: 0.0000e+00
# Epoch 19/150
# 34/34 - 8s - loss: 0.0487 - accuracy: 0.1245 - val_loss: 0.0835 - val_accuracy: 0.1196
# Epoch 20/150
# 34/34 - 7s - loss: 0.0335 - accuracy: 0.0956 - val_loss: 0.0977 - val_accuracy: 0.0000e+00
# Epoch 21/150
# 34/34 - 7s - loss: 0.0231 - accuracy: 0.1414 - val_loss: 0.2164 - val_accuracy: 0.0000e+00
# Epoch 22/150
# 34/34 - 7s - loss: 0.0260 - accuracy: 0.1096 - val_loss: 0.1174 - val_accuracy: 0.0543
# Epoch 23/150
# 34/34 - 7s - loss: 0.0262 - accuracy: 0.1434 - val_loss: 0.6191 - val_accuracy: 0.3949
# Epoch 24/150
# 34/34 - 7s - loss: 0.0216 - accuracy: 0.1648 - val_loss: 0.2018 - val_accuracy: 0.3949
# Epoch 25/150
# 34/34 - 7s - loss: 0.0151 - accuracy: 0.1891 - val_loss: 0.1458 - val_accuracy: 0.2572
# Epoch 26/150
# 34/34 - 7s - loss: 0.0136 - accuracy: 0.1976 - val_loss: 0.1142 - val_accuracy: 0.3406
# Epoch 27/150
# 34/34 - 7s - loss: 0.0148 - accuracy: 0.1882 - val_loss: 0.1038 - val_accuracy: 0.0109
# Epoch 28/150
# 34/34 - 7s - loss: 0.0101 - accuracy: 0.1742 - val_loss: 0.0913 - val_accuracy: 0.2681
# Epoch 29/150
# 34/34 - 7s - loss: 0.0177 - accuracy: 0.1957 - val_loss: 0.5733 - val_accuracy: 0.1123
# Epoch 30/150
# 34/34 - 7s - loss: 0.0096 - accuracy: 0.1863 - val_loss: 0.0843 - val_accuracy: 0.2065
# Epoch 31/150
# 34/34 - 7s - loss: 0.0279 - accuracy: 0.1976 - val_loss: 3.3209 - val_accuracy: 0.0000e+00
# Epoch 32/150
# 34/34 - 7s - loss: 0.0156 - accuracy: 0.2397 - val_loss: 3.2267 - val_accuracy: 0.0000e+00
# Epoch 33/150
# 34/34 - 7s - loss: 0.0291 - accuracy: 0.2228 - val_loss: 0.0911 - val_accuracy: 0.2609
# Epoch 34/150
# 34/34 - 7s - loss: 0.0340 - accuracy: 0.2191 - val_loss: 4.9899 - val_accuracy: 0.4819
# Epoch 35/150
# 34/34 - 7s - loss: 0.0386 - accuracy: 0.1770 - val_loss: 2.2095 - val_accuracy: 0.0036
# Epoch 36/150
# 34/34 - 7s - loss: 0.0181 - accuracy: 0.1695 - val_loss: 0.1790 - val_accuracy: 0.1159
# Epoch 37/150
# 34/34 - 7s - loss: 0.0119 - accuracy: 0.2200 - val_loss: 0.2241 - val_accuracy: 0.4457
# Epoch 38/150
# 34/34 - 7s - loss: 0.0168 - accuracy: 0.2116 - val_loss: 0.2965 - val_accuracy: 0.0109
# Epoch 39/150
# 34/34 - 8s - loss: 0.0080 - accuracy: 0.2182 - val_loss: 0.1414 - val_accuracy: 0.1812
# Epoch 40/150
# 34/34 - 7s - loss: 0.0106 - accuracy: 0.2406 - val_loss: 0.1233 - val_accuracy: 0.2319
# Epoch 41/150
# 34/34 - 7s - loss: 0.0172 - accuracy: 0.2238 - val_loss: 0.1077 - val_accuracy: 0.1304
# Epoch 42/150
# 34/34 - 7s - loss: 0.0277 - accuracy: 0.2341 - val_loss: 3.2274 - val_accuracy: 0.0000e+00
# Epoch 43/150
# 34/34 - 7s - loss: 0.0139 - accuracy: 0.2107 - val_loss: 0.2363 - val_accuracy: 0.0000e+00
# Epoch 44/150
# 34/34 - 7s - loss: 0.0068 - accuracy: 0.2228 - val_loss: 0.1846 - val_accuracy: 0.0036
# Epoch 45/150
# 34/34 - 7s - loss: 0.0115 - accuracy: 0.2210 - val_loss: 0.1436 - val_accuracy: 0.1594
# Epoch 46/150
# 34/34 - 7s - loss: 0.0081 - accuracy: 0.2322 - val_loss: 0.1058 - val_accuracy: 0.2899
# Epoch 47/150
# 34/34 - 7s - loss: 0.0173 - accuracy: 0.2331 - val_loss: 0.1102 - val_accuracy: 0.2029
# Epoch 48/150
# 34/34 - 7s - loss: 0.0131 - accuracy: 0.2247 - val_loss: 0.0950 - val_accuracy: 0.2464
# Epoch 49/150
# 34/34 - 7s - loss: 0.0036 - accuracy: 0.2556 - val_loss: 0.1136 - val_accuracy: 0.3370
# Epoch 50/150
# 34/34 - 7s - loss: 0.0155 - accuracy: 0.2472 - val_loss: 0.1067 - val_accuracy: 0.3261
# Epoch 51/150
# 34/34 - 7s - loss: 0.0228 - accuracy: 0.1835 - val_loss: 0.2196 - val_accuracy: 0.2826
# Epoch 52/150
# 34/34 - 7s - loss: 0.0139 - accuracy: 0.2341 - val_loss: 0.2075 - val_accuracy: 0.0072
# Epoch 53/150
# 34/34 - 7s - loss: 0.0041 - accuracy: 0.2444 - val_loss: 0.1417 - val_accuracy: 0.4203
# Epoch 54/150
# 34/34 - 7s - loss: 0.0076 - accuracy: 0.2781 - val_loss: 0.2362 - val_accuracy: 0.0217
# Epoch 55/150
# 34/34 - 7s - loss: 0.0124 - accuracy: 0.2528 - val_loss: 0.1112 - val_accuracy: 0.3442
# Epoch 56/150
# 34/34 - 7s - loss: 0.0080 - accuracy: 0.2800 - val_loss: 0.1028 - val_accuracy: 0.3007
# Epoch 57/150
# 34/34 - 7s - loss: 0.0119 - accuracy: 0.2640 - val_loss: 0.1285 - val_accuracy: 0.1630
# Epoch 58/150
# 34/34 - 7s - loss: 0.0077 - accuracy: 0.2781 - val_loss: 0.0897 - val_accuracy: 0.3768
# Epoch 59/150
# 34/34 - 7s - loss: 0.0127 - accuracy: 0.2978 - val_loss: 0.4910 - val_accuracy: 0.0254
# Epoch 60/150
# 34/34 - 7s - loss: 0.0057 - accuracy: 0.2631 - val_loss: 0.2710 - val_accuracy: 0.0725
# Epoch 61/150
# 34/34 - 7s - loss: 0.0047 - accuracy: 0.2678 - val_loss: 0.1233 - val_accuracy: 0.2609
# Epoch 62/150
# 34/34 - 7s - loss: 0.0075 - accuracy: 0.2687 - val_loss: 0.1168 - val_accuracy: 0.3261
# Epoch 63/150
# 34/34 - 7s - loss: 0.0133 - accuracy: 0.2715 - val_loss: 0.7639 - val_accuracy: 0.1667
# Epoch 64/150
# 34/34 - 7s - loss: 0.0043 - accuracy: 0.2547 - val_loss: 0.0905 - val_accuracy: 0.2536
# Epoch 65/150
# 34/34 - 8s - loss: 0.0053 - accuracy: 0.2837 - val_loss: 0.1389 - val_accuracy: 0.3551
# Epoch 66/150
# 34/34 - 7s - loss: 0.0084 - accuracy: 0.2856 - val_loss: 0.7854 - val_accuracy: 0.0109
# Epoch 67/150
# 34/34 - 7s - loss: 0.0069 - accuracy: 0.2809 - val_loss: 2.7277 - val_accuracy: 0.0000e+00
# Epoch 68/150
# 34/34 - 7s - loss: 0.0061 - accuracy: 0.2978 - val_loss: 0.1040 - val_accuracy: 0.3442
# Epoch 69/150
# 34/34 - 7s - loss: 0.0153 - accuracy: 0.2949 - val_loss: 0.2414 - val_accuracy: 0.0435
# Epoch 70/150
# 34/34 - 7s - loss: 0.0130 - accuracy: 0.2921 - val_loss: 0.1093 - val_accuracy: 0.3261
# Epoch 71/150
# 34/34 - 7s - loss: 0.0093 - accuracy: 0.3287 - val_loss: 0.1821 - val_accuracy: 0.0181
# Epoch 72/150
# 34/34 - 7s - loss: 0.0032 - accuracy: 0.3371 - val_loss: 0.0929 - val_accuracy: 0.4022
# Epoch 73/150
# 34/34 - 8s - loss: 0.0064 - accuracy: 0.3408 - val_loss: 0.0737 - val_accuracy: 0.2717
# Epoch 74/150
# 34/34 - 7s - loss: 0.0140 - accuracy: 0.3390 - val_loss: 0.1322 - val_accuracy: 0.0326
# Epoch 75/150
# 34/34 - 7s - loss: 0.0042 - accuracy: 0.3090 - val_loss: 0.1158 - val_accuracy: 0.3333
# Epoch 76/150
# 34/34 - 7s - loss: 0.0034 - accuracy: 0.3043 - val_loss: 0.1187 - val_accuracy: 0.2355
# Epoch 77/150
# 34/34 - 7s - loss: 0.0025 - accuracy: 0.3287 - val_loss: 0.0956 - val_accuracy: 0.3442
# Epoch 78/150
# 34/34 - 7s - loss: 0.0118 - accuracy: 0.3240 - val_loss: 0.1105 - val_accuracy: 0.4094
# Epoch 79/150
# 34/34 - 6s - loss: 0.0194 - accuracy: 0.2865 - val_loss: 0.0935 - val_accuracy: 0.3080
# Epoch 80/150
# 34/34 - 7s - loss: 0.0144 - accuracy: 0.2903 - val_loss: 0.6832 - val_accuracy: 0.0000e+00
# Epoch 81/150
# 34/34 - 7s - loss: 0.0062 - accuracy: 0.2987 - val_loss: 0.1088 - val_accuracy: 0.4203
# Epoch 82/150
# 34/34 - 7s - loss: 0.0049 - accuracy: 0.2893 - val_loss: 0.1017 - val_accuracy: 0.4203
# Epoch 83/150
# 34/34 - 7s - loss: 0.0032 - accuracy: 0.2706 - val_loss: 0.1285 - val_accuracy: 0.4565
# Epoch 84/150
# 34/34 - 7s - loss: 0.0021 - accuracy: 0.2978 - val_loss: 0.1170 - val_accuracy: 0.4348
# Epoch 85/150
# 34/34 - 6s - loss: 0.0026 - accuracy: 0.2818 - val_loss: 0.1433 - val_accuracy: 0.1667
# Epoch 86/150
# 34/34 - 7s - loss: 0.0058 - accuracy: 0.3062 - val_loss: 0.1066 - val_accuracy: 0.1812
# Epoch 87/150
# 34/34 - 7s - loss: 0.0016 - accuracy: 0.2949 - val_loss: 0.0892 - val_accuracy: 0.3551
# Epoch 88/150
# 34/34 - 7s - loss: 0.0015 - accuracy: 0.3174 - val_loss: 0.0945 - val_accuracy: 0.4239
# Epoch 89/150
# 34/34 - 7s - loss: 0.0022 - accuracy: 0.3502 - val_loss: 0.1007 - val_accuracy: 0.3406
# Epoch 90/150
# 34/34 - 6s - loss: 0.0011 - accuracy: 0.3258 - val_loss: 0.0952 - val_accuracy: 0.3623
# Epoch 91/150
# 34/34 - 7s - loss: 0.0128 - accuracy: 0.3399 - val_loss: 1.2679 - val_accuracy: 0.4457
# Epoch 92/150
# 34/34 - 7s - loss: 0.0052 - accuracy: 0.3184 - val_loss: 0.1241 - val_accuracy: 0.4094
# Epoch 93/150
# 34/34 - 7s - loss: 0.0024 - accuracy: 0.3343 - val_loss: 0.1023 - val_accuracy: 0.3406
# Epoch 94/150
# 34/34 - 7s - loss: 0.0030 - accuracy: 0.3511 - val_loss: 0.3331 - val_accuracy: 0.0072
# Epoch 95/150
# 34/34 - 6s - loss: 0.0042 - accuracy: 0.3212 - val_loss: 1.0348 - val_accuracy: 0.0181
# Epoch 96/150
# 34/34 - 7s - loss: 0.0040 - accuracy: 0.3155 - val_loss: 2.2893 - val_accuracy: 0.0000e+00
# Epoch 97/150
# 34/34 - 7s - loss: 0.0020 - accuracy: 0.3305 - val_loss: 0.4566 - val_accuracy: 0.0580
# Epoch 98/150
# 34/34 - 7s - loss: 0.0018 - accuracy: 0.3352 - val_loss: 0.5192 - val_accuracy: 0.0543
# Epoch 99/150
# 34/34 - 7s - loss: 0.0026 - accuracy: 0.3305 - val_loss: 1.1586 - val_accuracy: 0.0036
# Epoch 100/150
# 34/34 - 7s - loss: 0.0026 - accuracy: 0.3427 - val_loss: 0.9929 - val_accuracy: 0.0036
# Epoch 101/150
# 34/34 - 7s - loss: 0.0016 - accuracy: 0.3558 - val_loss: 0.1149 - val_accuracy: 0.3986
# Epoch 102/150
# 34/34 - 7s - loss: 0.0028 - accuracy: 0.3596 - val_loss: 0.1218 - val_accuracy: 0.4565
# Epoch 103/150
# 34/34 - 7s - loss: 0.0018 - accuracy: 0.3680 - val_loss: 0.1242 - val_accuracy: 0.4529
# Epoch 104/150
# 34/34 - 7s - loss: 0.0029 - accuracy: 0.3605 - val_loss: 0.1350 - val_accuracy: 0.4529
# Epoch 105/150
# 34/34 - 6s - loss: 0.0026 - accuracy: 0.3642 - val_loss: 0.1117 - val_accuracy: 0.1812
# Epoch 106/150
# 34/34 - 7s - loss: 0.0034 - accuracy: 0.3642 - val_loss: 0.0996 - val_accuracy: 0.3986
# Epoch 107/150
# 34/34 - 7s - loss: 0.0032 - accuracy: 0.3652 - val_loss: 2.1375 - val_accuracy: 0.0000e+00
# Epoch 108/150
# 34/34 - 6s - loss: 0.0014 - accuracy: 0.3717 - val_loss: 0.1315 - val_accuracy: 0.4601
# Epoch 109/150
# 34/34 - 7s - loss: 0.0045 - accuracy: 0.3287 - val_loss: 0.1069 - val_accuracy: 0.2065
# Epoch 110/150
# 34/34 - 7s - loss: 0.0020 - accuracy: 0.3277 - val_loss: 0.1731 - val_accuracy: 0.3804
# Epoch 111/150
# 34/34 - 7s - loss: 0.0054 - accuracy: 0.3511 - val_loss: 0.1521 - val_accuracy: 0.3116
# Epoch 112/150
# 34/34 - 7s - loss: 0.0013 - accuracy: 0.3455 - val_loss: 0.1250 - val_accuracy: 0.1993
# Epoch 113/150
# 34/34 - 6s - loss: 0.0024 - accuracy: 0.3474 - val_loss: 0.1240 - val_accuracy: 0.3514
# Epoch 114/150
# 34/34 - 7s - loss: 2.4946e-04 - accuracy: 0.3586 - val_loss: 0.1195 - val_accuracy: 0.3986
# Epoch 115/150
# 34/34 - 7s - loss: 0.0025 - accuracy: 0.3361 - val_loss: 0.1412 - val_accuracy: 0.4601
# Epoch 116/150
# 34/34 - 7s - loss: 0.0012 - accuracy: 0.3455 - val_loss: 0.1552 - val_accuracy: 0.4638
# Epoch 117/150
# 34/34 - 7s - loss: 0.0010 - accuracy: 0.3558 - val_loss: 0.1305 - val_accuracy: 0.4384
# Epoch 118/150
# 34/34 - 7s - loss: 0.0020 - accuracy: 0.3633 - val_loss: 0.1400 - val_accuracy: 0.4493
# Epoch 119/150
# 34/34 - 7s - loss: 0.0040 - accuracy: 0.3792 - val_loss: 0.1613 - val_accuracy: 0.2754
# Epoch 120/150
# 34/34 - 7s - loss: 0.0079 - accuracy: 0.3624 - val_loss: 0.1660 - val_accuracy: 0.2790
# Epoch 121/150
# 34/34 - 6s - loss: 0.0022 - accuracy: 0.3614 - val_loss: 0.2081 - val_accuracy: 0.2210
# Epoch 122/150
# 34/34 - 7s - loss: 0.0037 - accuracy: 0.3502 - val_loss: 0.0803 - val_accuracy: 0.1993
# Epoch 123/150
# 34/34 - 7s - loss: 0.0010 - accuracy: 0.3764 - val_loss: 0.1160 - val_accuracy: 0.4312
# Epoch 124/150
# 34/34 - 7s - loss: 0.0011 - accuracy: 0.3914 - val_loss: 0.1186 - val_accuracy: 0.4022
# Epoch 125/150
# 34/34 - 7s - loss: 0.0013 - accuracy: 0.3736 - val_loss: 0.2199 - val_accuracy: 0.1159
# Epoch 126/150
# 34/34 - 7s - loss: 0.0031 - accuracy: 0.3708 - val_loss: 0.1846 - val_accuracy: 0.1957
# Epoch 127/150
# 34/34 - 7s - loss: 0.0070 - accuracy: 0.3558 - val_loss: 3.7569 - val_accuracy: 0.0000e+00
# Epoch 128/150
# 34/34 - 7s - loss: 0.0028 - accuracy: 0.3820 - val_loss: 0.1621 - val_accuracy: 0.4674
# Epoch 129/150
# 34/34 - 7s - loss: 0.0056 - accuracy: 0.3811 - val_loss: 0.1108 - val_accuracy: 0.4529
# Epoch 130/150
# 34/34 - 7s - loss: 0.0028 - accuracy: 0.3851 - val_loss: 1.3826 - val_accuracy: 0.2464
# Epoch 131/150
# 34/34 - 6s - loss: 0.0048 - accuracy: 0.3530 - val_loss: 0.1041 - val_accuracy: 0.2138
# Epoch 132/150
# 34/34 - 7s - loss: 7.5405e-04 - accuracy: 0.3539 - val_loss: 0.0940 - val_accuracy: 0.3442
# Epoch 133/150
# 34/34 - 7s - loss: 0.0040 - accuracy: 0.3642 - val_loss: 0.1351 - val_accuracy: 0.2065
# Epoch 134/150
# 34/34 - 7s - loss: 0.0021 - accuracy: 0.3858 - val_loss: 0.1211 - val_accuracy: 0.4529
# Epoch 135/150
# 34/34 - 7s - loss: 0.0016 - accuracy: 0.3989 - val_loss: 0.1310 - val_accuracy: 0.4674
# Epoch 136/150
# 34/34 - 7s - loss: 5.8114e-04 - accuracy: 0.3904 - val_loss: 0.1307 - val_accuracy: 0.4746
# Epoch 137/150
# 34/34 - 7s - loss: 0.0044 - accuracy: 0.3745 - val_loss: 2.9340 - val_accuracy: 0.0000e+00
# Epoch 138/150
# 34/34 - 7s - loss: 4.0272e-04 - accuracy: 0.3801 - val_loss: 0.2270 - val_accuracy: 0.0616
# Epoch 139/150
# 34/34 - 7s - loss: 0.0084 - accuracy: 0.3839 - val_loss: 5.2098 - val_accuracy: 0.4819
# Epoch 140/150
# 34/34 - 7s - loss: 0.0020 - accuracy: 0.3895 - val_loss: 0.1751 - val_accuracy: 0.4203
# Epoch 141/150
# 34/34 - 6s - loss: 0.0030 - accuracy: 0.3811 - val_loss: 0.1001 - val_accuracy: 0.3986
# Epoch 142/150
# 34/34 - 7s - loss: 7.8070e-04 - accuracy: 0.3614 - val_loss: 0.0953 - val_accuracy: 0.3949
# Epoch 143/150
# 34/34 - 7s - loss: 0.0012 - accuracy: 0.3773 - val_loss: 0.0893 - val_accuracy: 0.3551
# Epoch 144/150
# 34/34 - 7s - loss: 4.2334e-04 - accuracy: 0.3886 - val_loss: 0.0882 - val_accuracy: 0.3696
# Epoch 145/150
# 34/34 - 7s - loss: 0.0029 - accuracy: 0.3876 - val_loss: 0.0769 - val_accuracy: 0.1920
# Epoch 146/150
# 34/34 - 7s - loss: 0.0050 - accuracy: 0.3708 - val_loss: 0.0845 - val_accuracy: 0.3913
# Epoch 147/150
# 34/34 - 7s - loss: 0.0013 - accuracy: 0.3652 - val_loss: 0.0845 - val_accuracy: 0.3768
# Epoch 148/150
# 34/34 - 7s - loss: 0.0057 - accuracy: 0.3558 - val_loss: 2.5016 - val_accuracy: 0.0036
# Epoch 149/150
# 34/34 - 7s - loss: 0.0044 - accuracy: 0.3989 - val_loss: 0.0758 - val_accuracy: 0.3696
# Epoch 150/150
# 34/34 - 7s - loss: 5.1952e-04 - accuracy: 0.3858 - val_loss: 0.0864 - val_accuracy: 0.3986

# %% [markdown]
# ## Performance do Modelo

# %%
model_NN = tf.keras.models.load_model('model_NN.h5')
model_CNN = tf.keras.models.load_model('model_CNN.h5')

# %%
def plot_accuracy_hist(model_history, fig_title):

    plt.rcParams.update({'font.size': 14})

    fig = plt.figure(figsize = (16, 4))
    columns = 2
    rows = 1

    fig.suptitle(fig_title, fontsize = 20, y = 1.08)
    fig.add_subplot(rows, columns, 1)

    plt.title('Accuracy')
    plt.ylim(0.6, 1)
    
    plt.plot(model_history.history['accuracy'], 
             color='green', 
             label = 'Train Accuracy')

    plt.plot(model_history.history['val_accuracy'], 
             color='red', 
             label = 'Test Accuracy', 
             linestyle='dashed')

    plt.legend()

    fig.add_subplot(rows, columns, 2)

    plt.title('Loss')
    plt.plot(model_history.history['loss'], 
             color='green', 
             label = 'Train Loss')

    plt.plot(model_history.history['val_loss'], 
             color='red', 
             label = 'Test Loss', 
             linestyle='dashed')

    plt.legend()

    plt.show()
    
plot_accuracy_hist(history_NN, 'Neural Network')
plot_accuracy_hist(history_CNN, 'Convolutional Neural Network')

# %% [markdown]
# ### Confusion Matrix

# %%
plt.rcParams.update({'font.size': 16})

def plot_confusion_mtx(model, x_test, plot_tittle):
    pred_prob = model.predict(x_test, batch_size = 8)
    pred = np.where(pred_prob > 0.5, 1,0)

    CM = confusion_matrix(y_test, pred)

    plot_confusion_matrix(conf_mat = CM, figsize = (16, 8))
    plt.title(plot_tittle)
    plt.xticks(range(2), labels)
    plt.yticks(range(2), labels)

    plt.show()

plot_confusion_mtx(model_NN, x_test, 'Neural Network')
plot_confusion_mtx(model_CNN, x_test, 'Convolutional Neural Network')

# %% [markdown]
# ### Receiver Operating Characteristic

# %%
pred_prob_NN  = model_NN.predict(x_test, batch_size = 8)
pred_prob_CNN = model_CNN.predict(x_test, batch_size = 8)

pred_NN  = np.where(pred_prob_NN > 0.5, 1,0)
pred_CNN = np.where(pred_prob_CNN > 0.5, 1,0)

NN_fpr, NN_tpr, _ = roc_curve(y_test, pred_prob_NN)
NN_roc_auc = auc(NN_fpr, NN_tpr)

CNN_fpr, CNN_tpr, _ = roc_curve(y_test, pred_prob_CNN)
CNN_roc_auc = auc(CNN_fpr, CNN_tpr)

plt.rcParams.update({'font.size': 16})

fig = plt.figure(figsize = (8, 6))

lw = 2
plt.plot(CNN_fpr,
         CNN_tpr, 
         color = 'darkorange',
         lw = lw, 
         label = 'CNN - ROC curve (area = %0.2f)' % CNN_roc_auc)

plt.plot(NN_fpr,
         NN_tpr, 
         color = 'grey',
         lw = lw, 
         label = '  NN - ROC curve (area = %0.2f)' % NN_roc_auc)

plt.plot([0, 1], [0, 1], 
         color = 'navy', 
         lw = lw, 
         linestyle = '--')

plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])

plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')

plt.title('Receiver operating characteristic')
plt.legend(loc = "lower right")

plt.show()

print('Classification Report - Neural Network')
print(classification_report(y_test, pred_NN))

print('\nClassification Report - Convolutional Neural Network')
print(classification_report(y_test, pred_CNN))
# Out:
# Classification Report - Neural Network
#               precision    recall  f1-score   support
#
#            0       0.90      0.92      0.91       138
#            1       0.92      0.90      0.91       138
#
#     accuracy                           0.91       276
#    macro avg       0.91      0.91      0.91       276
# weighted avg       0.91      0.91      0.91       276
#
#
# Classification Report - Convolutional Neural Network
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       138
#            1       0.99      0.99      0.99       138
#
#     accuracy                           0.99       276
#    macro avg       0.99      0.99      0.99       276
# weighted avg       0.99      0.99      0.99       276
